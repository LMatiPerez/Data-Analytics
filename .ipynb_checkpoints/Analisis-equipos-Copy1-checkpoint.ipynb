# %%
# 1° Carga de tablas, aprolijamiento, creación de nuevas columnas y cambio de type a INT.
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

BIGDATA=pd.read_excel('Jugadores-CopaBinance2022.xlsx',sheet_name='BIGDATA',index_col='Nombre')
GLOBAL=pd.read_excel('Equipos-CopaBinance2022.xlsx',sheet_name='GLOBAL',index_col='Unnamed: 0').T
Tiempo1=pd.read_excel('Equipos-CopaBinance2022.xlsx',sheet_name='1TIEMPO',index_col='Unnamed: 0').T
Tiempo2=pd.read_excel('Equipos-CopaBinance2022.xlsx',sheet_name='2TIEMPO',index_col='Unnamed: 0').T
GLOBAL = GLOBAL[GLOBAL['Regates'].notna()]
Vacios = GLOBAL[ GLOBAL['Posesión de balón'] == ' ' ].index
GLOBAL.drop(Vacios , inplace=True)
Tiempo1 = Tiempo1[Tiempo1['Regates'].notna()]
Vacios = Tiempo1[ Tiempo1['Posesión de balón'] == ' ' ].index
Tiempo1.drop(Vacios , inplace=True)
Tiempo2 = Tiempo2[Tiempo2['Regates'].notna()]
Vacios = Tiempo2[ Tiempo2['Posesión de balón'] == ' ' ].index
Tiempo2.drop(Vacios , inplace=True)
#### Agregado de Rival-Resultado-Condicion a BIGDATA
Fixture=pd.read_excel('ResultadosCopaBinance2022.xlsx')
ContadorFixture=0
inicio=0
BIGDATA['Resultado']=""
BIGDATA['Rival']=''
BIGDATA['Condicion']=''
BIGDATA['Local']=''
BIGDATA['Visitante']=''
BIGDATA['Partido']=''
for i in range(0,len(BIGDATA.index)):
    if BIGDATA['Equipo'].iloc[i]==Fixture['Local'][ContadorFixture]:
        BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
        BIGDATA['Condicion'][i]='Home'
        BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
        BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
        BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]
    elif BIGDATA['Equipo'].iloc[i]==Fixture['Visitante'][ContadorFixture]:
        BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
        BIGDATA['Condicion'][i]='Away'
        BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
        BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
        BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
    else:
        for a in range(inicio,i):
            BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]      
        inicio=i
        ContadorFixture=ContadorFixture+1
        if BIGDATA['Equipo'].iloc[i]==Fixture['Local'][ContadorFixture]:
            BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
            BIGDATA['Condicion'][i]='Home'
            BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
            BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
            BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]   
        else:
            BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
            BIGDATA['Condicion'][i]='Away'
            BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
            BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
            BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
for a in range(inicio,i+1):
    BIGDATA['Resultado'][a]=BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]   
####
BIGDATA.insert(loc = 4, column = 'Goles y Asistencias', value = BIGDATA['Goles']+BIGDATA['Asistencias'])
### Numerizando GLOBAL
GLOBAL['Posesión de balón']=GLOBAL['Posesión de balón'].astype('float64')*100
GLOBAL[['Tiros totales', 'Tiros a puerta', 'Tiros fuera','Disparos bloqueados', 'Saques de esquina', 'Fueras de juego',
        'Faltas','Tarjetas amarillas', 'Tarjetas rojas', 'Ocasiones claras','Ocasiones claras falladas', 'Disparos al Palo',
        'Contraataques','Tiros en contraataque', 'Goles en contraataque','Tiros dentro del área',
        'Tiros desde fuera del área', 'Paradas','Pases', 'Pases totales', 'Porc. Pases efectivos','Pases largos efectivos',
        'Pases largos totales','Porc. Pases largos efectivos', 'Centros completados','Centros intentados',
        'Porc. Centros completados','Regates completados', 'Regates intentados', 'Porc. Regates efectivos','Posesión perdida',
        'Duelos ganados', 'Balones aéreos ganados','Entradas', 'Intercepciones', 'Despejes']]=GLOBAL[['Tiros totales', 'Tiros a puerta', 'Tiros fuera',
       'Disparos bloqueados', 'Saques de esquina', 'Fueras de juego', 'Faltas','Tarjetas amarillas', 'Tarjetas rojas','Ocasiones claras',
       'Ocasiones claras falladas', 'Disparos al Palo', 'Contraataques','Tiros en contraataque', 'Goles en contraataque',
       'Tiros dentro del área', 'Tiros desde fuera del área', 'Paradas','Pases', 'Pases totales', 'Porc. Pases efectivos',
       'Pases largos efectivos', 'Pases largos totales','Porc. Pases largos efectivos', 'Centros completados',
       'Centros intentados', 'Porc. Centros completados','Regates completados', 'Regates intentados', 'Porc. Regates efectivos',
       'Posesión perdida', 'Duelos ganados', 'Balones aéreos ganados','Entradas', 'Intercepciones', 'Despejes']].astype('int64')
####
pd.options.display.max_columns = None

# %%
#2° Nueva creación de columnas, relacionadas a lo que generó el rival en contra y nuevas columnas en base a dos metricas.
GLOBAL=GLOBAL.loc[GLOBAL['Posesión de balón']>0]
GLOBAL.rename(columns={'Pases totales':'Pases acertados','Disparos al Palo':'Disparos al palo','Pases':'Pases totales'},inplace=True)
GLOBAL=GLOBAL.drop(['Centros', 'Regates','Pases acierte','Pases largos'], axis=1)
GLOBAL['Porc. Tiros a puerta']=GLOBAL['Tiros a puerta']/GLOBAL['Tiros totales']
GLOBAL['Pases por cada perdida']=GLOBAL['Pases totales']/GLOBAL['Posesión perdida']
GLOBAL['Porc. Tiros dentro del área']=GLOBAL['Tiros dentro del área']/GLOBAL['Tiros totales']
GLOBAL['Porc. Tiros fuera del área']=GLOBAL['Tiros desde fuera del área']/GLOBAL['Tiros totales']
Rival=['Posesión de balón Rival', 'Tiros totales Rival', 'Tiros a puerta Rival', 'Tiros fuera Rival',
       'Disparos bloqueados Rival', 'Saques de esquina Rival', 'Fueras de juego Rival', 'Faltas Rival',
       'Tarjetas amarillas Rival', 'Tarjetas rojas Rival', 'Ocasiones claras Rival',
       'Ocasiones claras falladas Rival', 'Disparos al palo Rival', 'Contraataques Rival',
       'Tiros en contraataque Rival', 'Goles en contraataque Rival',
       'Tiros dentro del área Rival', 'Tiros desde fuera del área Rival', 'Paradas Rival',
       'Pases totales Rival', 'Pases acertados Rival', 'Porc. Pases efectivos Rival',
       'Pases largos efectivos Rival', 'Pases largos totales Rival',
       'Porc. Pases largos efectivos Rival', 'Centros completados Rival',
       'Centros intentados Rival', 'Porc. Centros completados Rival',
       'Regates completados Rival', 'Regates intentados Rival', 'Porc. Regates efectivos Rival',
       'Posesión perdida Rival', 'Duelos ganados Rival', 'Balones aéreos ganados Rival',
       'Entradas Rival', 'Intercepciones Rival', 'Despejes Rival', 'Rival',
       'Porc. Tiros a puerta Rival','Pases por cada perdida Rival',
       'Porc. Tiros dentro del área Rival','Porc. Tiros fuera del área Rival']
Lista=['Posesión de balón', 'Tiros totales', 'Tiros a puerta', 'Tiros fuera',
       'Disparos bloqueados', 'Saques de esquina', 'Fueras de juego', 'Faltas',
       'Tarjetas amarillas', 'Tarjetas rojas', 'Ocasiones claras',
       'Ocasiones claras falladas', 'Disparos al palo', 'Contraataques',
       'Tiros en contraataque', 'Goles en contraataque',
       'Tiros dentro del área', 'Tiros desde fuera del área', 'Paradas',
       'Pases totales', 'Pases acertados', 'Porc. Pases efectivos',
       'Pases largos efectivos', 'Pases largos totales',
       'Porc. Pases largos efectivos', 'Centros completados',
       'Centros intentados', 'Porc. Centros completados',
       'Regates completados', 'Regates intentados', 'Porc. Regates efectivos',
       'Posesión perdida', 'Duelos ganados', 'Balones aéreos ganados',
       'Entradas', 'Intercepciones', 'Despejes', 'equipo',
       'Porc. Tiros a puerta','Pases por cada perdida','Porc. Tiros dentro del área','Porc. Tiros fuera del área']
GLOBAL[Rival]=0
for a,b in zip(Lista,Rival):  
    for i in range(1,int(len(GLOBAL)/2)+1):
        GLOBAL[b][i*2-1]=GLOBAL[a][i*2]
        GLOBAL[b][i*2]=GLOBAL[a][i*2-1]
GLOBAL['Goles Rival']=GLOBAL['Tiros a puerta Rival']-GLOBAL['Paradas']
GLOBAL['Goles']=GLOBAL['Tiros a puerta']-GLOBAL['Paradas Rival']
GLOBAL['Goles x Tiros totales']=GLOBAL['Goles']/GLOBAL['Tiros totales']
GLOBAL['Goles x Tiros a puerta']=GLOBAL['Goles']/GLOBAL['Tiros a puerta']
GLOBAL['Goles x Tiros totales Rival']=GLOBAL['Goles Rival']/GLOBAL['Tiros totales Rival']
GLOBAL['Goles x Tiros a puerta Rival']=GLOBAL['Goles Rival']/GLOBAL['Tiros a puerta Rival']

# %%
#3° Formato de tabla acumulada, agrupación por equipos de la labor durante todo el torneo y nuevas columnas surgidas
# de nuevas metricas.
Partidos=GLOBAL.groupby('equipo').count()['Posesión de balón'][0]
GLOBAL=GLOBAL.groupby('equipo').sum()

GLOBAL['Goles x Tiros totales']=GLOBAL['Goles']/GLOBAL['Tiros totales']
GLOBAL['Goles x Tiros a puerta']=GLOBAL['Goles']/GLOBAL['Tiros a puerta']
GLOBAL['Goles x Tiros totales Rival']=GLOBAL['Goles Rival']/GLOBAL['Tiros totales Rival']
GLOBAL['Goles x Tiros a puerta Rival']=GLOBAL['Goles Rival']/GLOBAL['Tiros a puerta Rival']
GLOBAL['Porc. Tiros a puerta']=GLOBAL['Tiros a puerta']/GLOBAL['Tiros totales']
GLOBAL['Pases por cada perdida']=GLOBAL['Pases totales']/GLOBAL['Posesión perdida']
GLOBAL['Porc. Tiros dentro del área']=GLOBAL['Tiros dentro del área']/GLOBAL['Tiros totales']
GLOBAL['Porc. Tiros fuera del área']=GLOBAL['Tiros desde fuera del área']/GLOBAL['Tiros totales']
GLOBAL['Porc. Tiros a puerta Rival']=GLOBAL['Tiros a puerta Rival']/GLOBAL['Tiros totales Rival']
GLOBAL['Pases por cada perdida Rival']=GLOBAL['Pases totales Rival']/GLOBAL['Posesión perdida Rival']
GLOBAL['Porc. Tiros dentro del área Rival']=GLOBAL['Tiros dentro del área Rival']/GLOBAL['Tiros totales Rival']
GLOBAL['Porc. Tiros fuera del área Rival']=GLOBAL['Tiros desde fuera del área Rival']/GLOBAL['Tiros totales Rival']
GLOBAL['Posesión de balón']=GLOBAL['Posesión de balón']/Partidos
GLOBAL['Posesión de balón Rival']=GLOBAL['Posesión de balón Rival']/Partidos
GLOBAL['Porc. Pases efectivos']=GLOBAL['Pases acertados']/GLOBAL['Pases totales']
GLOBAL['Porc. Pases largos efectivos']=GLOBAL['Pases largos efectivos']/GLOBAL['Pases largos totales']
GLOBAL['Porc. Centros completados']=GLOBAL['Centros intentados']/GLOBAL['Centros completados']
GLOBAL['Porc. Regates efectivos']=GLOBAL['Regates completados']/GLOBAL['Regates intentados']
GLOBAL['Porc. Pases efectivos Rival']=GLOBAL['Pases acertados Rival']/GLOBAL['Pases totales Rival']
GLOBAL['Porc. Pases largos efectivos Rival']=GLOBAL['Pases largos efectivos Rival']/GLOBAL['Pases largos totales Rival']
GLOBAL['Porc. Centros completados Rival']=GLOBAL['Centros intentados Rival']/GLOBAL['Centros completados Rival']
GLOBAL['Porc. Regates efectivos Rival']=GLOBAL['Regates completados Rival']/GLOBAL['Regates intentados Rival']

# %%
## Opcion 4.1 Analisis de equipos TODAS LAS METRICAS - Proporciona graficas de los 10 mejores equipos en cada Métrica con
# sus respectivos valores.
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.image as image

print(GLOBAL.columns)
listas=['Posesión perdida']
lista=['Posesión de balón', 'Tiros totales', 'Tiros a puerta', 'Tiros fuera',
       'Disparos bloqueados', 'Saques de esquina', 'Fueras de juego', 'Faltas',
       'Tarjetas amarillas', 'Tarjetas rojas', 'Ocasiones claras',
       'Ocasiones claras falladas', 'Disparos al Palo', 'Contraataques',
       'Tiros en contraataque', 'Goles en contraataque',
       'Tiros dentro del área', 'Tiros desde fuera del área', 'Paradas',
       'Pases', 'Pases totales', 'Porc. Pases efectivos',
       'Pases largos efectivos', 'Pases largos totales',
       'Porc. Pases largos efectivos', 'Centros completados',
       'Centros intentados', 'Porc. Centros completados',
       'Regates completados', 'Regates intentados', 'Porc. Regates efectivos',
       'Posesión perdida', 'Duelos ganados', 'Balones aéreos ganados',
       'Entradas', 'Intercepciones', 'Despejes']
for a in GLOBAL.columns: 
    #if a=='Pases acierte'or a=='Pases largos' or a=='Centros' or a=='Regates':
        #print('hola')
    #else:
        parametro=a
        #[parametro]
        #1equipo=GLOBAL.groupby(['equipo']).sum().sort_values(by=[parametro],ascending= False).head(10).index
        equipo=GLOBAL.sort_values(by=a,ascending= False).head(10).index
        #1dato=GLOBAL.groupby(['equipo']).sum().sort_values(by=[parametro],ascending= False)[parametro].head(10)
        abscisa=equipo
        cantidad = GLOBAL.sort_values(by=a,ascending= False)[a].head(10)
        #1if a=='Posesión de balón':
            #1cantidad = (GLOBAL.groupby(['equipo']).sum()/GLOBAL.groupby(['equipo']).count()).sort_values(by=['Posesión de balón'],ascending= False)['Posesión de balón'].head(10)
        #1else:
            #1cantidad = GLOBAL.groupby(['equipo']).sum().sort_values(by=[parametro],ascending= False)[parametro].head(10)
        #imput=input()
        #beto=imput+".png"
        
        # Funciones para la inserción de logo
        
        def scale(im, nR, nC):
            """
            parameters
            im :image
            nR:row size
            nC:column size 
            Return: scaled image 
            """
            number_rows = len(im)     # source number of rows 
            number_columns = len(im[0])  # source number of columns 
            return [[ im[int(number_rows * r / nR)][int(number_columns * c / nC)]  
                         for c in range(nC)] for r in range(nR)]
        def watermark(ax,x0,y0):
            """
            adds image logo and positions it on the plot
            ax: figure object 
            x0: adds x 
            y0: adds y 
            """
            img = plt.imread('Copita.png')
            #scale Image
            img =scale(img, 800, 800)


            #print('transData(0,0) = {}'.format(ax.transData.transform((0,0))))
            ax.figure.figimage(img, x0,y0, alpha=.65, zorder=1,origin="upper")
        
        # Figure Size & customization
        fig, ax = plt.subplots(figsize =(16, 9))
        watermark(ax,4150,200) #Imagen logo - Opcional
        ax.barh(abscisa, cantidad,height=0.65 ,color=['#c3514e', '#e6bab7', '#e6bab7', '#c3514e', '#c3514e','#bfbebe', '#bfbebe', '#bfbebe', '#bfbebe', '#bfbebe'])
        #colores: #c3514e rojo oscuro, #e6bab7 rosa, #bfbebe gris, #8a796e gris oscuro 
        
        # -otra opcion de color- fig.patch.set_facecolor('xkcd:dark')
        # -otra opcion de color- ax.set_facecolor('xkcd:dark')
        fig.patch.set_facecolor('w')
        ax.set_facecolor('w')
        
        # Remove axes splines
        for s in ['top', 'bottom', 'left', 'right']:
            ax.spines[s].set_visible(False)

        # Remove x, y Ticks
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')

        # Add padding between axes and labels
        #ax.xaxis.set_tick_params(pad = 5,colors='linen')
        # - otra opción de color- ax.yaxis.set_tick_params(pad = 10,colors='linen',labelsize=16)
        ax.yaxis.set_tick_params(pad = 10,colors='#68666a',labelsize=19)
        ax.axes.get_xaxis().set_visible(False)

        # Add x, y gridlines
        ax.grid(b = True, color ='w',
                linestyle ='-.', linewidth = 0.5,
                alpha = 0.2)

        # Show top values
        ax.invert_yaxis()

        # Add annotation to bars - se debe modificar los valores del eje x por la variación que presenta cada tabla
        for i in ax.patches:
            plt.text(i.get_width()*0.95, i.get_y()+0.5,
                     str(round((i.get_width()), 2)),
                     fontsize = 16,fontweight ='bold',
                     color ='w')
        #height = rect.get_height()
        #rect.get_x() - rect.get_width() / 5
        #ax.tick_params(axis='x', colors='red')
        #ax.tick_params(axis='y', colors='red') 
        
        # Add Plot Title
        ax.set_title(parametro+' - Copa de la Liga Argentina',
                     loc ='left', color='#68666a',fontsize = 25)

        # Add Text watermark
        fig.text(1.03, 0.17, '@Mati_9_Perez', fontsize = 15,
                 color ='#68666a', ha ='right', va ='bottom',
                 alpha = 0.6)

        # Show Plot
plt.show()
        # -otro formato- fig.savefig('myimage.svg', format='svg', dpi=1200)
        # -otro formato- plt.savefig('destination_path.eps', format='eps')
        #fig.savefig(parametro+' Equipos'+' F6.png', dpi = 300,bbox_inches="tight") ATENCION! GUARDA TODAS LAS METRICAS
        # -example dpi1200- fig.savefig('plot_name1200.png', dpi = 1200)

# %%
# Opcion 4.2a Reporte de métricas destacadas por equipo en lo que va del torneo. Posiciones de 1° a 5°, hay parámetros
# positivos y parametros negativos.

for m in GLOBAL.index:
    print(m)
    print(' ')
    for a in GLOBAL.keys():
        for i in range(0,5):
            if GLOBAL.sort_values(by=a,ascending=False).index[i]==m:
                print('--> '+str(i+1)+'° en '+a+' ['+str(round(GLOBAL.sort_values(by=a,ascending=False)[a].iloc[i],2))+']')
    print('---------------------Fin equipo------------------------------------')
# Out:
# Aldosivi
#
# --> 3° en Contraataques [2]
# --> 3° en Tiros en contraataque [2]
# --> 2° en Paradas [26]
# --> 3° en Pases largos totales [371]
# --> 1° en Porc. Centros completados [9.25]
# --> 4° en Intercepciones [69]
# --> 3° en Porc. Tiros fuera del área [0.54]
# --> 2° en Tiros a puerta Rival [33]
# --> 5° en Tiros fuera Rival [35]
# --> 2° en Saques de esquina Rival [32]
# --> 2° en Fueras de juego Rival [19]
# --> 1° en Tarjetas rojas Rival [3]
# --> 1° en Goles en contraataque Rival [1]
# --> 2° en Tiros dentro del área Rival [48]
# --> 3° en Pases largos totales Rival [363]
# --> 5° en Centros completados Rival [28]
# --> 1° en Porc. Regates efectivos Rival [0.59]
# --> 2° en Porc. Tiros a puerta Rival [0.43]
# --> 4° en Porc. Tiros dentro del área Rival [0.62]
# ---------------------Fin equipo------------------------------------
# Argentinos Jrs
#
# --> 2° en Posesión de balón [62.2]
# --> 4° en Ocasiones claras [11]
# --> 4° en Ocasiones claras falladas [8]
# --> 4° en Tiros en contraataque [2]
# --> 3° en Pases totales [2417]
# --> 2° en Pases acertados [1985]
# --> 1° en Porc. Pases efectivos [0.82]
# --> 5° en Porc. Pases largos efectivos [0.52]
# --> 5° en Regates completados [52]
# --> 1° en Pases por cada perdida [3.26]
# --> 5° en Porc. Tiros fuera del área [0.5]
# --> 5° en Fueras de juego Rival [16]
# --> 3° en Tarjetas amarillas Rival [17]
# --> 5° en Ocasiones claras falladas Rival [7]
# --> 2° en Contraataques Rival [4]
# ---------------------Fin equipo------------------------------------
# Arsenal
#
# --> 5° en Tiros fuera [32]
# --> 2° en Saques de esquina [33]
# --> 4° en Faltas [81]
# --> 5° en Contraataques [2]
# --> 5° en Tiros en contraataque [2]
# --> 1° en Despejes [135]
# --> 1° en Posesión de balón Rival [59.4]
# --> 4° en Tarjetas amarillas Rival [16]
# --> 5° en Disparos al palo Rival [2]
# --> 3° en Pases totales Rival [2121]
# --> 1° en Pases largos efectivos Rival [178]
# --> 5° en Pases largos totales Rival [348]
# --> 4° en Porc. Pases largos efectivos Rival [0.51]
# --> 2° en Centros completados Rival [37]
# --> 2° en Centros intentados Rival [128]
# --> 2° en Posesión perdida Rival [887]
# --> 2° en Goles Rival [9]
# --> 1° en Goles x Tiros a puerta [0.54]
# ---------------------Fin equipo------------------------------------
# Atl. Tucuman
#
# --> 3° en Disparos bloqueados [20]
# --> 4° en Tarjetas amarillas [17]
# --> 5° en Centros intentados [117]
# --> 2° en Porc. Centros completados [5.57]
# --> 4° en Posesión perdida [862]
# --> 5° en Paradas Rival [17]
# --> 5° en Porc. Centros completados Rival [5.11]
# --> 4° en Posesión perdida Rival [847]
# --> 3° en Goles Rival [8]
# --> 3° en Goles x Tiros totales Rival [0.14]
# ---------------------Fin equipo------------------------------------
# Banfield
#
# --> 4° en Tiros totales [75]
# --> 3° en Tiros fuera [35]
# --> 4° en Disparos bloqueados [20]
# --> 3° en Fueras de juego [14]
# --> 5° en Tarjetas amarillas [17]
# --> 5° en Tiros dentro del área [42]
# --> 5° en Tiros desde fuera del área [33]
# --> 2° en Centros completados [31]
# --> 5° en Balones aéreos ganados [104]
# --> 3° en Intercepciones [69]
# --> 4° en Despejes [115]
# --> 5° en Balones aéreos ganados Rival [105]
# --> 1° en Despejes Rival [122]
# --> 3° en Goles [9]
# --> 4° en Goles x Tiros a puerta [0.45]
# ---------------------Fin equipo------------------------------------
# Barracas Ctral.
#
# --> 3° en Paradas [20]
# --> 4° en Porc. Tiros a puerta [0.4]
# --> 3° en Posesión de balón Rival [57.2]
# --> 3° en Tiros totales Rival [82]
# --> 3° en Tiros a puerta Rival [30]
# --> 3° en Disparos bloqueados Rival [22]
# --> 1° en Fueras de juego Rival [23]
# --> 1° en Ocasiones claras Rival [20]
# --> 1° en Ocasiones claras falladas Rival [15]
# --> 3° en Contraataques Rival [4]
# --> 5° en Tiros en contraataque Rival [3]
# --> 2° en Goles en contraataque Rival [1]
# --> 1° en Tiros dentro del área Rival [51]
# --> 5° en Pases acertados Rival [1648]
# --> 5° en Porc. Pases efectivos Rival [0.78]
# --> 2° en Pases largos efectivos Rival [176]
# --> 2° en Porc. Pases largos efectivos Rival [0.52]
# --> 5° en Porc. Tiros a puerta Rival [0.37]
# --> 5° en Porc. Tiros dentro del área Rival [0.62]
# --> 1° en Goles Rival [10]
# ---------------------Fin equipo------------------------------------
# Boca
#
# --> 5° en Tiros a puerta [24]
# --> 2° en Goles en contraataque [1]
# --> 2° en Tiros dentro del área [46]
# --> 3° en Porc. Pases efectivos [0.8]
# --> 4° en Entradas [104]
# --> 4° en Pases por cada perdida [2.88]
# --> 1° en Porc. Tiros dentro del área [0.73]
# --> 2° en Porc. Regates efectivos Rival [0.58]
# --> 2° en Porc. Tiros fuera del área Rival [0.54]
# --> 4° en Goles x Tiros totales Rival [0.13]
# ---------------------Fin equipo------------------------------------
# CA Huracan
#
# --> 1° en Tarjetas amarillas [19]
# --> 4° en Pases largos efectivos [178]
# --> 5° en Pases largos totales [351]
# --> 3° en Tiros fuera Rival [37]
# --> 2° en Tarjetas rojas Rival [3]
# --> 4° en Pases acertados Rival [1674]
# --> 2° en Porc. Pases efectivos Rival [0.8]
# --> 4° en Centros intentados Rival [119]
# --> 4° en Regates completados Rival [53]
# --> 4° en Regates intentados Rival [100]
# --> 1° en Pases por cada perdida Rival [2.96]
# --> 3° en Goles x Tiros totales [0.15]
# --> 1° en Goles x Tiros a puerta Rival [0.45]
# ---------------------Fin equipo------------------------------------
# Central CBA
#
# --> 1° en Tiros totales [81]
# --> 1° en Tiros fuera [48]
# --> 5° en Fueras de juego [13]
# --> 3° en Ocasiones claras [11]
# --> 2° en Ocasiones claras falladas [9]
# --> 4° en Tiros dentro del área [42]
# --> 2° en Tiros desde fuera del área [39]
# --> 1° en Pases largos efectivos [192]
# --> 1° en Pases largos totales [398]
# --> 4° en Balones aéreos ganados [105]
# --> 5° en Entradas [96]
# --> 5° en Intercepciones [66]
# --> 3° en Ocasiones claras Rival [11]
# --> 4° en Tiros en contraataque Rival [3]
# --> 2° en Pases largos totales Rival [364]
# --> 4° en Porc. Centros completados Rival [5.31]
# --> 2° en Intercepciones Rival [77]
# ---------------------Fin equipo------------------------------------
# Colon
#
# --> 3° en Porc. Centros completados [5.53]
# --> 4° en Tiros fuera Rival [36]
# --> 1° en Contraataques Rival [5]
# --> 1° en Tiros en contraataque Rival [5]
# --> 5° en Tiros desde fuera del área Rival [36]
# --> 4° en Pases totales Rival [2110]
# --> 3° en Pases acertados Rival [1686]
# --> 1° en Porc. Pases efectivos Rival [0.8]
# --> 5° en Pases largos efectivos Rival [163]
# --> 5° en Porc. Pases largos efectivos Rival [0.51]
# --> 5° en Porc. Regates efectivos Rival [0.57]
# --> 2° en Entradas Rival [109]
# --> 2° en Pases por cada perdida Rival [2.9]
# --> 5° en Porc. Tiros fuera del área Rival [0.49]
# --> 5° en Goles [8]
# --> 5° en Goles x Tiros totales [0.14]
# --> 5° en Goles x Tiros a puerta [0.44]
# ---------------------Fin equipo------------------------------------
# Def. y Justicia
#
# --> 3° en Tiros a puerta [28]
# --> 4° en Tarjetas rojas [1]
# --> 4° en Pases totales [2152]
# --> 4° en Pases acertados [1721]
# --> 2° en Porc. Pases efectivos [0.8]
# --> 4° en Regates completados [53]
# --> 2° en Porc. Regates efectivos [0.62]
# --> 3° en Despejes [116]
# --> 5° en Porc. Tiros a puerta [0.39]
# --> 2° en Pases por cada perdida [3.22]
# --> 4° en Tiros totales Rival [79]
# --> 5° en Tiros a puerta Rival [23]
# --> 5° en Disparos bloqueados Rival [21]
# --> 4° en Saques de esquina Rival [32]
# --> 4° en Fueras de juego Rival [17]
# --> 2° en Tiros desde fuera del área Rival [40]
# --> 1° en Porc. Pases largos efectivos Rival [0.52]
# --> 1° en Centros completados Rival [41]
# --> 1° en Centros intentados Rival [142]
# --> 1° en Regates completados Rival [62]
# --> 1° en Regates intentados Rival [109]
# --> 4° en Porc. Regates efectivos Rival [0.57]
# --> 3° en Porc. Tiros fuera del área Rival [0.51]
# --> 1° en Goles [13]
# --> 1° en Goles x Tiros totales [0.18]
# --> 3° en Goles x Tiros a puerta [0.46]
# ---------------------Fin equipo------------------------------------
# Estudiantes LP
#
# --> 2° en Posesión perdida [869]
# --> 2° en Balones aéreos ganados [119]
# --> 5° en Despejes [114]
# --> 5° en Saques de esquina Rival [31]
# --> 2° en Tarjetas amarillas Rival [19]
# --> 5° en Centros intentados Rival [117]
# --> 2° en Porc. Centros completados Rival [6.5]
# --> 1° en Posesión perdida Rival [889]
# --> 3° en Balones aéreos ganados Rival [110]
# --> 2° en Goles [11]
# --> 2° en Goles x Tiros totales [0.17]
# --> 2° en Goles x Tiros a puerta [0.48]
# --> 5° en Goles x Tiros totales Rival [0.13]
# --> 5° en Goles x Tiros a puerta Rival [0.41]
# ---------------------Fin equipo------------------------------------
# Gimnasia LP
#
# --> 1° en Tiros a puerta [29]
# --> 2° en Tarjetas amarillas [18]
# --> 1° en Tiros desde fuera del área [41]
# --> 4° en Regates intentados [102]
# --> 4° en Duelos ganados [303]
# --> 2° en Porc. Tiros a puerta [0.4]
# --> 2° en Porc. Tiros fuera del área [0.57]
# --> 5° en Tiros totales Rival [78]
# --> 1° en Tiros fuera Rival [37]
# --> 4° en Disparos bloqueados Rival [21]
# --> 1° en Faltas Rival [86]
# --> 1° en Tarjetas amarillas Rival [19]
# --> 3° en Tiros dentro del área Rival [47]
# --> 1° en Paradas Rival [24]
# --> 3° en Porc. Pases efectivos Rival [0.79]
# --> 4° en Entradas Rival [104]
# --> 3° en Pases por cada perdida Rival [2.86]
# --> 5° en Goles Rival [8]
# ---------------------Fin equipo------------------------------------
# Godoy Cruz
#
# --> 3° en Tiros totales [75]
# --> 2° en Tiros fuera [38]
# --> 5° en Saques de esquina [32]
# --> 2° en Tarjetas rojas [3]
# --> 5° en Ocasiones claras [11]
# --> 2° en Contraataques [4]
# --> 2° en Tiros en contraataque [3]
# --> 5° en Goles en contraataque [1]
# --> 3° en Tiros dentro del área [45]
# --> 5° en Pases largos efectivos [173]
# --> 4° en Porc. Pases largos efectivos [0.52]
# --> 1° en Centros completados [32]
# --> 1° en Regates completados [62]
# --> 2° en Regates intentados [109]
# --> 5° en Porc. Regates efectivos [0.57]
# --> 4° en Disparos al palo Rival [2]
# --> 1° en Porc. Centros completados Rival [7.33]
# --> 3° en Regates completados Rival [54]
# --> 3° en Regates intentados Rival [100]
# --> 5° en Entradas Rival [102]
# --> 2° en Despejes Rival [114]
# --> 4° en Goles Rival [8]
# --> 2° en Goles x Tiros totales Rival [0.15]
# --> 2° en Goles x Tiros a puerta Rival [0.42]
# ---------------------Fin equipo------------------------------------
# Independiente
#
# --> 5° en Posesión de balón [55.6]
# --> 1° en Saques de esquina [35]
# --> 2° en Centros intentados [125]
# --> 3° en Tarjetas rojas Rival [2]
# --> 1° en Disparos al palo Rival [4]
# --> 5° en Contraataques Rival [3]
# --> 3° en Tiros en contraataque Rival [3]
# --> 1° en Entradas Rival [118]
# --> 5° en Intercepciones Rival [67]
# --> 5° en Despejes Rival [106]
# --> 4° en Goles x Tiros a puerta Rival [0.41]
# ---------------------Fin equipo------------------------------------
# Lanus
#
# --> 3° en Posesión de balón [58.4]
# --> 4° en Fueras de juego [13]
# --> 2° en Pases totales [2456]
# --> 3° en Pases acertados [1917]
# --> 5° en Regates intentados [98]
# --> 3° en Posesión perdida [863]
# --> 5° en Pases por cada perdida [2.85]
# --> 5° en Porc. Tiros dentro del área [0.64]
# --> 5° en Faltas Rival [77]
# --> 5° en Ocasiones claras Rival [10]
# --> 4° en Ocasiones claras falladas Rival [7]
# --> 1° en Intercepciones Rival [92]
# --> 4° en Despejes Rival [111]
# --> 3° en Goles x Tiros a puerta Rival [0.42]
# ---------------------Fin equipo------------------------------------
# Newell´s
#
# --> 2° en Fueras de juego [14]
# --> 1° en Faltas [87]
# --> 4° en Contraataques [2]
# --> 5° en Centros completados [31]
# --> 2° en Posesión de balón Rival [58.2]
# --> 4° en Tiros a puerta Rival [24]
# --> 2° en Ocasiones claras Rival [12]
# --> 3° en Ocasiones claras falladas Rival [7]
# --> 2° en Disparos al palo Rival [4]
# --> 1° en Pases totales Rival [2254]
# --> 1° en Pases acertados Rival [1765]
# --> 3° en Pases largos efectivos Rival [165]
# --> 3° en Porc. Pases largos efectivos Rival [0.52]
# --> 2° en Regates completados Rival [55]
# --> 5° en Regates intentados Rival [96]
# --> 3° en Porc. Regates efectivos Rival [0.57]
# --> 2° en Duelos ganados Rival [301]
# --> 4° en Porc. Tiros a puerta Rival [0.39]
# --> 4° en Pases por cada perdida Rival [2.85]
# ---------------------Fin equipo------------------------------------
# Patronato
#
# --> 1° en Disparos bloqueados [24]
# --> 3° en Faltas [83]
# --> 3° en Disparos al palo [3]
# --> 4° en Centros completados [31]
# --> 1° en Centros intentados [132]
# --> 1° en Posesión perdida [906]
# --> 5° en Tarjetas rojas Rival [1]
# --> 5° en Goles en contraataque Rival [1]
# --> 1° en Pases largos totales Rival [388]
# --> 3° en Posesión perdida Rival [850]
# --> 1° en Duelos ganados Rival [308]
# --> 4° en Balones aéreos ganados Rival [109]
# --> 3° en Despejes Rival [111]
# --> 1° en Porc. Tiros a puerta Rival [0.51]
# --> 1° en Porc. Tiros dentro del área Rival [0.71]
# --> 1° en Goles x Tiros totales Rival [0.17]
# ---------------------Fin equipo------------------------------------
# Platense
#
# --> 4° en Goles en contraataque [1]
# --> 2° en Despejes [116]
# --> 2° en Disparos bloqueados Rival [25]
# --> 3° en Saques de esquina Rival [32]
# --> 4° en Faltas Rival [82]
# --> 3° en Tiros desde fuera del área Rival [40]
# --> 1° en Porc. Tiros fuera del área Rival [0.56]
# ---------------------Fin equipo------------------------------------
# Racing Club
#
# --> 2° en Tiros totales [79]
# --> 2° en Disparos bloqueados [24]
# --> 3° en Saques de esquina [33]
# --> 1° en Ocasiones claras [14]
# --> 1° en Ocasiones claras falladas [9]
# --> 3° en Goles en contraataque [1]
# --> 1° en Tiros dentro del área [47]
# --> 5° en Pases totales [2124]
# --> 5° en Pases acertados [1644]
# --> 2° en Pases largos efectivos [184]
# --> 1° en Porc. Pases largos efectivos [0.54]
# --> 3° en Centros completados [31]
# --> 4° en Centros intentados [120]
# --> 3° en Porc. Regates efectivos [0.59]
# --> 4° en Contraataques Rival [4]
# --> 2° en Tiros en contraataque Rival [4]
# ---------------------Fin equipo------------------------------------
# River
#
# --> 1° en Posesión de balón [65.2]
# --> 4° en Tiros a puerta [26]
# --> 4° en Saques de esquina [32]
# --> 2° en Ocasiones claras [13]
# --> 3° en Ocasiones claras falladas [8]
# --> 1° en Disparos al palo [6]
# --> 1° en Pases totales [2732]
# --> 1° en Pases acertados [2167]
# --> 4° en Porc. Pases efectivos [0.79]
# --> 3° en Pases largos efectivos [181]
# --> 2° en Porc. Pases largos efectivos [0.53]
# --> 5° en Posesión perdida [856]
# --> 1° en Porc. Tiros a puerta [0.42]
# --> 3° en Pases por cada perdida [3.19]
# --> 2° en Porc. Tiros dentro del área [0.66]
# --> 4° en Centros completados Rival [29]
# --> 5° en Posesión perdida Rival [841]
# --> 3° en Intercepciones Rival [73]
# --> 3° en Porc. Tiros dentro del área Rival [0.66]
# --> 4° en Goles [9]
# --> 4° en Goles x Tiros totales [0.15]
# ---------------------Fin equipo------------------------------------
# Rosario Ctral.
#
# --> 4° en Posesión de balón [57.8]
# --> 5° en Ocasiones claras falladas [6]
# --> 5° en Disparos al palo [2]
# --> 3° en Centros intentados [120]
# --> 4° en Ocasiones claras Rival [10]
# --> 4° en Goles en contraataque Rival [1]
# --> 2° en Porc. Tiros dentro del área Rival [0.67]
# ---------------------Fin equipo------------------------------------
# San Lorenzo
#
# --> 1° en Fueras de juego [16]
# --> 1° en Paradas [28]
# --> 1° en Regates intentados [110]
# --> 3° en Duelos ganados [305]
# --> 2° en Entradas [108]
# --> 1° en Porc. Tiros fuera del área [0.62]
# --> 4° en Posesión de balón Rival [57.0]
# --> 2° en Tiros totales Rival [82]
# --> 1° en Tiros a puerta Rival [35]
# --> 1° en Saques de esquina Rival [36]
# --> 3° en Faltas Rival [82]
# --> 2° en Ocasiones claras falladas Rival [7]
# --> 5° en Tiros dentro del área Rival [44]
# --> 4° en Tiros desde fuera del área Rival [38]
# --> 2° en Pases totales Rival [2160]
# --> 2° en Pases acertados Rival [1699]
# --> 4° en Porc. Pases efectivos Rival [0.79]
# --> 3° en Centros completados Rival [30]
# --> 5° en Duelos ganados Rival [293]
# --> 3° en Entradas Rival [108]
# --> 3° en Porc. Tiros a puerta Rival [0.43]
# --> 5° en Pases por cada perdida Rival [2.76]
# ---------------------Fin equipo------------------------------------
# Sarmiento
#
# --> 2° en Tiros a puerta [28]
# --> 2° en Faltas [85]
# --> 3° en Tiros desde fuera del área [37]
# --> 4° en Paradas [18]
# --> 4° en Pases largos totales [351]
# --> 1° en Balones aéreos ganados [136]
# --> 3° en Porc. Tiros a puerta [0.4]
# --> 4° en Porc. Tiros fuera del área [0.53]
# --> 1° en Tiros totales Rival [88]
# --> 2° en Tiros fuera Rival [37]
# --> 1° en Disparos bloqueados Rival [28]
# --> 5° en Tarjetas amarillas Rival [16]
# --> 3° en Disparos al palo Rival [3]
# --> 3° en Goles en contraataque Rival [1]
# --> 4° en Tiros dentro del área Rival [44]
# --> 1° en Tiros desde fuera del área Rival [44]
# --> 2° en Paradas Rival [22]
# --> 3° en Centros intentados Rival [128]
# --> 2° en Balones aéreos ganados Rival [110]
# --> 4° en Porc. Tiros fuera del área Rival [0.5]
# ---------------------Fin equipo------------------------------------
# Talleres
#
# --> 5° en Faltas [78]
# --> 3° en Tarjetas amarillas [18]
# --> 1° en Tarjetas rojas [3]
# --> 4° en Disparos al palo [2]
# --> 2° en Pases largos totales [374]
# --> 5° en Duelos ganados [303]
# --> 3° en Balones aéreos ganados [112]
# --> 2° en Intercepciones [72]
# --> 3° en Porc. Tiros dentro del área [0.65]
# --> 3° en Duelos ganados Rival [298]
# ---------------------Fin equipo------------------------------------
# Tigre
#
# --> 5° en Tiros totales [75]
# --> 4° en Tiros fuera [34]
# --> 5° en Disparos bloqueados [20]
# --> 1° en Contraataques [9]
# --> 1° en Tiros en contraataque [8]
# --> 1° en Goles en contraataque [1]
# --> 4° en Tiros desde fuera del área [35]
# --> 3° en Porc. Pases largos efectivos [0.52]
# --> 2° en Regates completados [61]
# --> 3° en Regates intentados [106]
# --> 4° en Porc. Regates efectivos [0.58]
# --> 2° en Duelos ganados [321]
# --> 3° en Entradas [107]
# --> 4° en Paradas Rival [17]
# --> 5° en Pases totales Rival [2109]
# --> 4° en Pases largos efectivos Rival [164]
# --> 3° en Porc. Centros completados Rival [5.63]
# --> 5° en Regates completados Rival [51]
# --> 2° en Regates intentados Rival [102]
# ---------------------Fin equipo------------------------------------
# Union
#
# --> 5° en Tarjetas rojas [1]
# --> 5° en Paradas [17]
# --> 5° en Porc. Centros completados [5.28]
# --> 3° en Regates completados [59]
# --> 1° en Porc. Regates efectivos [0.65]
# --> 4° en Porc. Tiros dentro del área [0.64]
# --> 5° en Posesión de balón Rival [56.2]
# --> 3° en Fueras de juego Rival [19]
# --> 4° en Pases largos totales Rival [354]
# --> 4° en Duelos ganados Rival [293]
# --> 1° en Balones aéreos ganados Rival [115]
# --> 4° en Intercepciones Rival [72]
# ---------------------Fin equipo------------------------------------
# Velez Sarsfield
#
# --> 3° en Tarjetas rojas [2]
# --> 2° en Disparos al palo [3]
# --> 5° en Porc. Pases efectivos [0.79]
# --> 4° en Porc. Centros completados [5.42]
# --> 1° en Duelos ganados [330]
# --> 1° en Entradas [111]
# --> 1° en Intercepciones [76]
# --> 2° en Faltas Rival [85]
# --> 4° en Tarjetas rojas Rival [2]
# --> 3° en Paradas Rival [17]
# ---------------------Fin equipo------------------------------------

# %%
# Opcion 4.2b Reporte de métricas destacadas por equipo en lo que va del torneo. Posiciones de 24° a 28°(ultimos 5),
# hay parámetros positivos y parametros negativos.

for m in GLOBAL.index:
    print(m)
    print(' ')
    for a in GLOBAL.keys():
        for i in range(23,28):
            if GLOBAL.sort_values(by=a,ascending=False).index[i]==m:
                print('--> '+str(i+1)+'° en '+a+' ['+str(round(GLOBAL.sort_values(by=a,ascending=False)[a].iloc[i],2))+']')
    print('---------------------Fin equipo------------------------------------')
# Out:
# Aldosivi
#
# --> 25° en Tiros totales [48]
# --> 26° en Tiros a puerta [13]
# --> 27° en Tiros fuera [18]
# --> 28° en Saques de esquina [18]
# --> 27° en Ocasiones claras falladas [1]
# --> 27° en Tiros dentro del área [22]
# --> 28° en Centros completados [8]
# --> 27° en Centros intentados [74]
# --> 26° en Duelos ganados [245]
# --> 26° en Balones aéreos ganados [62]
# --> 26° en Porc. Tiros dentro del área [0.46]
# --> 26° en Disparos bloqueados Rival [9]
# --> 28° en Tarjetas amarillas Rival [7]
# --> 26° en Paradas Rival [9]
# --> 25° en Porc. Tiros fuera del área Rival [0.38]
# --> 24° en Goles x Tiros a puerta Rival [0.21]
# ---------------------Fin equipo------------------------------------
# Argentinos Jrs
#
# --> 24° en Fueras de juego [6]
# --> 25° en Tarjetas rojas [0]
# --> 24° en Pases largos totales [298]
# --> 24° en Balones aéreos ganados [62]
# --> 24° en Despejes [66]
# --> 24° en Porc. Tiros dentro del área [0.5]
# --> 27° en Posesión de balón Rival [37.8]
# --> 26° en Saques de esquina Rival [19]
# --> 27° en Pases totales Rival [1443]
# --> 27° en Pases acertados Rival [981]
# --> 27° en Porc. Pases efectivos Rival [0.68]
# --> 25° en Centros intentados Rival [79]
# --> 28° en Porc. Centros completados Rival [2.93]
# --> 26° en Porc. Regates efectivos Rival [0.45]
# --> 24° en Duelos ganados Rival [264]
# --> 27° en Pases por cada perdida Rival [1.95]
# ---------------------Fin equipo------------------------------------
# Arsenal
#
# --> 28° en Posesión de balón [40.4]
# --> 25° en Tiros a puerta [13]
# --> 24° en Ocasiones claras falladas [2]
# --> 27° en Goles en contraataque [0]
# --> 28° en Pases totales [1427]
# --> 28° en Pases acertados [913]
# --> 28° en Porc. Pases efectivos [0.64]
# --> 25° en Pases largos efectivos [121]
# --> 26° en Porc. Pases largos efectivos [0.37]
# --> 24° en Regates completados [33]
# --> 24° en Regates intentados [68]
# --> 28° en Porc. Tiros a puerta [0.21]
# --> 28° en Pases por cada perdida [1.69]
# --> 25° en Tarjetas rojas Rival [0]
# --> 26° en Contraataques Rival [0]
# --> 25° en Tiros en contraataque Rival [0]
# --> 27° en Goles en contraataque Rival [0]
# --> 28° en Paradas Rival [6]
# --> 28° en Regates completados Rival [31]
# --> 28° en Porc. Regates efectivos Rival [0.42]
# ---------------------Fin equipo------------------------------------
# Atl. Tucuman
#
# --> 24° en Ocasiones claras [5]
# --> 26° en Goles en contraataque [0]
# --> 27° en Regates completados [29]
# --> 25° en Regates intentados [65]
# --> 26° en Porc. Regates efectivos [0.45]
# --> 25° en Ocasiones claras Rival [4]
# --> 28° en Ocasiones claras falladas Rival [1]
# --> 25° en Contraataques Rival [0]
# --> 24° en Tiros en contraataque Rival [0]
# --> 26° en Goles en contraataque Rival [0]
# --> 24° en Porc. Pases efectivos Rival [0.7]
# --> 28° en Pases largos efectivos Rival [98]
# --> 28° en Porc. Pases largos efectivos Rival [0.32]
# --> 25° en Centros completados Rival [18]
# --> 27° en Goles [2]
# --> 27° en Goles x Tiros totales [0.03]
# --> 27° en Goles x Tiros a puerta [0.11]
# ---------------------Fin equipo------------------------------------
# Banfield
#
# --> 25° en Disparos al palo [0]
# --> 25° en Goles en contraataque [0]
# --> 25° en Pases totales [1547]
# --> 26° en Porc. Centros completados [3.29]
# --> 25° en Regates completados [31]
# --> 26° en Regates intentados [62]
# --> 24° en Duelos ganados [257]
# --> 27° en Entradas [66]
# --> 24° en Porc. Tiros a puerta [0.27]
# --> 24° en Pases por cada perdida [1.94]
# --> 26° en Faltas Rival [57]
# --> 24° en Ocasiones claras Rival [4]
# --> 27° en Disparos al palo Rival [0]
# --> 24° en Contraataques Rival [0]
# --> 25° en Goles en contraataque Rival [0]
# --> 26° en Regates intentados Rival [69]
# --> 25° en Entradas Rival [75]
# ---------------------Fin equipo------------------------------------
# Barracas Ctral.
#
# --> 26° en Posesión de balón [42.8]
# --> 28° en Tiros totales [43]
# --> 28° en Tiros fuera [17]
# --> 27° en Disparos bloqueados [9]
# --> 27° en Saques de esquina [18]
# --> 24° en Goles en contraataque [0]
# --> 26° en Tiros dentro del área [27]
# --> 28° en Tiros desde fuera del área [16]
# --> 27° en Pases totales [1530]
# --> 25° en Pases acertados [1047]
# --> 24° en Pases largos efectivos [121]
# --> 25° en Porc. Pases largos efectivos [0.37]
# --> 27° en Duelos ganados [244]
# --> 28° en Balones aéreos ganados [57]
# --> 27° en Tarjetas amarillas Rival [7]
# --> 27° en Tarjetas rojas Rival [0]
# --> 28° en Intercepciones Rival [38]
# --> 26° en Despejes Rival [70]
# --> 24° en Porc. Tiros fuera del área Rival [0.38]
# ---------------------Fin equipo------------------------------------
# Boca
#
# --> 25° en Tiros desde fuera del área [17]
# --> 26° en Posesión perdida [698]
# --> 28° en Porc. Tiros fuera del área [0.27]
# --> 24° en Tiros totales Rival [52]
# --> 24° en Tiros fuera Rival [22]
# --> 24° en Saques de esquina Rival [21]
# --> 26° en Tarjetas rojas Rival [0]
# --> 25° en Disparos al palo Rival [0]
# --> 24° en Goles en contraataque Rival [0]
# --> 28° en Tiros dentro del área Rival [24]
# --> 26° en Pases largos totales Rival [299]
# --> 26° en Porc. Centros completados Rival [3.19]
# --> 24° en Posesión perdida Rival [729]
# --> 26° en Duelos ganados Rival [252]
# --> 27° en Balones aéreos ganados Rival [61]
# --> 24° en Intercepciones Rival [45]
# --> 27° en Porc. Tiros dentro del área Rival [0.46]
# ---------------------Fin equipo------------------------------------
# CA Huracan
#
# --> 24° en Tiros fuera [21]
# --> 25° en Saques de esquina [19]
# --> 27° en Tarjetas rojas [0]
# --> 24° en Disparos al palo [0]
# --> 24° en Tiros dentro del área [29]
# --> 28° en Paradas [6]
# --> 27° en Posesión perdida [681]
# --> 26° en Intercepciones [44]
# --> 28° en Tiros a puerta Rival [11]
# --> 26° en Ocasiones claras Rival [3]
# --> 27° en Ocasiones claras falladas Rival [1]
# --> 24° en Pases largos efectivos Rival [124]
# --> 28° en Pases largos totales Rival [286]
# --> 28° en Posesión perdida Rival [711]
# --> 26° en Entradas Rival [74]
# --> 27° en Intercepciones Rival [41]
# --> 28° en Porc. Tiros a puerta Rival [0.19]
# ---------------------Fin equipo------------------------------------
# Central CBA
#
# --> 25° en Faltas [58]
# --> 26° en Porc. Tiros a puerta [0.22]
# --> 25° en Fueras de juego Rival [4]
# --> 27° en Faltas Rival [51]
# --> 24° en Tarjetas amarillas Rival [8]
# --> 24° en Tarjetas rojas Rival [0]
# --> 26° en Porc. Pases largos efectivos Rival [0.38]
# --> 27° en Centros completados Rival [16]
# --> 28° en Duelos ganados Rival [239]
# --> 27° en Entradas Rival [62]
# --> 25° en Goles x Tiros totales [0.05]
# ---------------------Fin equipo------------------------------------
# Colon
#
# --> 28° en Faltas [44]
# --> 26° en Tarjetas amarillas [9]
# --> 27° en Centros completados [15]
# --> 25° en Centros intentados [83]
# --> 25° en Duelos ganados [253]
# --> 28° en Fueras de juego Rival [2]
# --> 25° en Faltas Rival [59]
# --> 25° en Tarjetas amarillas Rival [7]
# --> 25° en Ocasiones claras falladas Rival [2]
# --> 24° en Paradas Rival [10]
# --> 25° en Posesión perdida Rival [728]
# --> 25° en Balones aéreos ganados Rival [69]
# --> 26° en Porc. Tiros a puerta Rival [0.23]
# --> 24° en Porc. Tiros dentro del área Rival [0.51]
# --> 25° en Goles x Tiros totales Rival [0.05]
# ---------------------Fin equipo------------------------------------
# Def. y Justicia
#
# --> 27° en Fueras de juego [4]
# --> 26° en Faltas [57]
# --> 26° en Centros completados [17]
# --> 28° en Centros intentados [66]
# --> 28° en Posesión perdida [669]
# --> 27° en Pases largos totales Rival [286]
# --> 24° en Balones aéreos ganados Rival [70]
# --> 26° en Intercepciones Rival [44]
# --> 26° en Porc. Tiros dentro del área Rival [0.49]
# ---------------------Fin equipo------------------------------------
# Estudiantes LP
#
# --> 24° en Paradas [10]
# --> 26° en Pases acertados [1037]
# --> 26° en Porc. Pases efectivos [0.66]
# --> 25° en Porc. Centros completados [3.41]
# --> 24° en Porc. Regates efectivos [0.45]
# --> 26° en Pases por cada perdida [1.81]
# --> 24° en Disparos bloqueados Rival [9]
# --> 24° en Ocasiones claras falladas Rival [2]
# --> 28° en Contraataques Rival [0]
# --> 27° en Tiros en contraataque Rival [0]
# --> 26° en Porc. Pases efectivos Rival [0.7]
# --> 25° en Porc. Pases largos efectivos Rival [0.38]
# --> 24° en Centros completados Rival [18]
# --> 25° en Intercepciones Rival [44]
# --> 26° en Pases por cada perdida Rival [2.04]
# ---------------------Fin equipo------------------------------------
# Gimnasia LP
#
# --> 26° en Tarjetas rojas [0]
# --> 28° en Pases largos totales [258]
# --> 25° en Posesión perdida [723]
# --> 24° en Intercepciones [47]
# --> 27° en Porc. Tiros dentro del área [0.43]
# --> 25° en Pases largos totales Rival [299]
# --> 26° en Posesión perdida Rival [715]
# --> 24° en Porc. Tiros a puerta Rival [0.26]
# --> 24° en Goles x Tiros a puerta [0.17]
# ---------------------Fin equipo------------------------------------
# Godoy Cruz
#
# --> 24° en Faltas [59]
# --> 28° en Tarjetas amarillas [7]
# --> 24° en Porc. Centros completados [3.5]
# --> 25° en Balones aéreos ganados [62]
# --> 28° en Despejes [47]
# --> 27° en Tiros fuera Rival [18]
# --> 28° en Faltas Rival [46]
# --> 24° en Tiros dentro del área Rival [29]
# --> 28° en Centros completados Rival [12]
# ---------------------Fin equipo------------------------------------
# Independiente
#
# --> 26° en Paradas [10]
# --> 26° en Pases largos totales [280]
# --> 25° en Porc. Regates efectivos [0.45]
# --> 27° en Saques de esquina Rival [19]
# --> 25° en Pases totales Rival [1572]
# --> 25° en Pases acertados Rival [1104]
# --> 25° en Porc. Pases efectivos Rival [0.7]
# --> 24° en Centros intentados Rival [81]
# --> 27° en Regates completados Rival [32]
# --> 25° en Regates intentados Rival [70]
# --> 24° en Porc. Regates efectivos Rival [0.46]
# ---------------------Fin equipo------------------------------------
# Lanus
#
# --> 27° en Tiros totales [44]
# --> 27° en Tiros a puerta [12]
# --> 25° en Tiros dentro del área [28]
# --> 27° en Tiros desde fuera del área [16]
# --> 27° en Paradas [7]
# --> 24° en Porc. Tiros fuera del área [0.36]
# --> 26° en Posesión de balón Rival [41.6]
# --> 26° en Tiros a puerta Rival [12]
# --> 28° en Tarjetas rojas Rival [0]
# --> 27° en Paradas Rival [7]
# --> 24° en Pases totales Rival [1682]
# --> 24° en Pases acertados Rival [1217]
# --> 27° en Porc. Regates efectivos Rival [0.43]
# --> 27° en Porc. Tiros a puerta Rival [0.2]
# --> 24° en Pases por cada perdida Rival [2.07]
# ---------------------Fin equipo------------------------------------
# Newell´s
#
# --> 27° en Posesión de balón [41.8]
# --> 25° en Disparos bloqueados [9]
# --> 24° en Tarjetas rojas [0]
# --> 28° en Porc. Centros completados [2.74]
# --> 27° en Porc. Regates efectivos [0.42]
# --> 28° en Saques de esquina Rival [18]
# --> 26° en Centros intentados Rival [77]
# --> 24° en Porc. Centros completados Rival [3.35]
# --> 27° en Despejes Rival [65]
# ---------------------Fin equipo------------------------------------
# Patronato
#
# --> 28° en Ocasiones claras [2]
# --> 25° en Porc. Pases efectivos [0.67]
# --> 28° en Pases largos efectivos [90]
# --> 28° en Porc. Pases largos efectivos [0.29]
# --> 26° en Regates completados [30]
# --> 28° en Porc. Regates efectivos [0.42]
# --> 27° en Intercepciones [43]
# --> 27° en Porc. Tiros a puerta [0.21]
# --> 27° en Pases por cada perdida [1.8]
# --> 27° en Tiros totales Rival [41]
# --> 25° en Tiros fuera Rival [18]
# --> 28° en Disparos bloqueados Rival [2]
# --> 26° en Tarjetas amarillas Rival [7]
# --> 28° en Tiros desde fuera del área Rival [12]
# --> 27° en Centros intentados Rival [72]
# --> 28° en Porc. Tiros fuera del área Rival [0.29]
# --> 28° en Goles [0]
# --> 28° en Goles x Tiros totales [0.0]
# --> 28° en Goles x Tiros a puerta [0.0]
# ---------------------Fin equipo------------------------------------
# Platense
#
# --> 27° en Faltas [55]
# --> 25° en Tarjetas amarillas [9]
# --> 28° en Tarjetas rojas [0]
# --> 27° en Pases largos efectivos [108]
# --> 27° en Porc. Pases largos efectivos [0.35]
# --> 28° en Tiros en contraataque Rival [0]
# --> 25° en Porc. Tiros a puerta Rival [0.24]
# --> 28° en Porc. Tiros dentro del área Rival [0.44]
# --> 25° en Goles Rival [3]
# --> 27° en Goles x Tiros totales Rival [0.04]
# --> 26° en Goles x Tiros a puerta Rival [0.18]
# ---------------------Fin equipo------------------------------------
# Racing Club
#
# --> 25° en Despejes [64]
# --> 24° en Posesión de balón Rival [44.2]
# --> 25° en Tiros dentro del área Rival [29]
# --> 28° en Centros intentados Rival [67]
# --> 27° en Porc. Centros completados Rival [3.19]
# --> 27° en Posesión perdida Rival [713]
# --> 27° en Duelos ganados Rival [247]
# --> 28° en Balones aéreos ganados Rival [55]
# --> 24° en Entradas Rival [75]
# --> 28° en Despejes Rival [65]
# ---------------------Fin equipo------------------------------------
# River
#
# --> 26° en Disparos bloqueados [9]
# --> 28° en Intercepciones [43]
# --> 27° en Porc. Tiros fuera del área [0.34]
# --> 28° en Posesión de balón Rival [34.8]
# --> 28° en Tiros totales Rival [41]
# --> 25° en Tiros a puerta Rival [13]
# --> 26° en Tiros fuera Rival [18]
# --> 25° en Saques de esquina Rival [20]
# --> 24° en Disparos al palo Rival [0]
# --> 26° en Tiros dentro del área Rival [27]
# --> 27° en Tiros desde fuera del área Rival [14]
# --> 28° en Pases totales Rival [1406]
# --> 28° en Pases acertados Rival [872]
# --> 28° en Porc. Pases efectivos Rival [0.62]
# --> 27° en Pases largos efectivos Rival [120]
# --> 27° en Porc. Pases largos efectivos Rival [0.36]
# --> 28° en Pases por cada perdida Rival [1.67]
# --> 26° en Porc. Tiros fuera del área Rival [0.34]
# --> 26° en Goles Rival [3]
# ---------------------Fin equipo------------------------------------
# Rosario Ctral.
#
# --> 25° en Fueras de juego [6]
# --> 24° en Contraataques [0]
# --> 24° en Tiros en contraataque [0]
# --> 27° en Regates intentados [61]
# --> 28° en Duelos ganados [226]
# --> 27° en Balones aéreos ganados [60]
# --> 26° en Entradas [68]
# --> 25° en Intercepciones [44]
# --> 27° en Despejes [58]
# --> 25° en Posesión de balón Rival [42.2]
# --> 25° en Tiros totales Rival [49]
# --> 27° en Disparos bloqueados Rival [7]
# --> 26° en Tiros desde fuera del área Rival [16]
# --> 26° en Pases totales Rival [1518]
# --> 26° en Pases acertados Rival [1075]
# --> 25° en Pases por cada perdida Rival [2.05]
# --> 27° en Porc. Tiros fuera del área Rival [0.33]
# ---------------------Fin equipo------------------------------------
# San Lorenzo
#
# --> 25° en Posesión de balón [43.0]
# --> 26° en Tiros totales [45]
# --> 28° en Tiros a puerta [12]
# --> 25° en Tiros fuera [19]
# --> 24° en Saques de esquina [19]
# --> 25° en Ocasiones claras [4]
# --> 26° en Disparos al palo [0]
# --> 25° en Contraataques [0]
# --> 25° en Tiros en contraataque [0]
# --> 28° en Tiros dentro del área [17]
# --> 26° en Pases largos efectivos [110]
# --> 25° en Pases largos totales [294]
# --> 24° en Porc. Pases largos efectivos [0.37]
# --> 24° en Centros intentados [84]
# --> 25° en Porc. Tiros a puerta [0.27]
# --> 28° en Porc. Tiros dentro del área [0.38]
# --> 24° en Fueras de juego Rival [4]
# --> 25° en Paradas Rival [9]
# --> 24° en Pases largos totales Rival [303]
# --> 25° en Porc. Centros completados Rival [3.33]
# --> 24° en Regates completados Rival [35]
# --> 25° en Porc. Regates efectivos Rival [0.45]
# --> 24° en Goles [3]
# --> 25° en Goles x Tiros a puerta Rival [0.2]
# ---------------------Fin equipo------------------------------------
# Sarmiento
#
# --> 25° en Ocasiones claras falladas [2]
# --> 27° en Disparos al palo [0]
# --> 26° en Contraataques [0]
# --> 26° en Tiros en contraataque [0]
# --> 26° en Pases totales [1546]
# --> 27° en Pases acertados [1014]
# --> 27° en Porc. Pases efectivos [0.66]
# --> 27° en Porc. Centros completados [3.14]
# --> 28° en Regates completados [20]
# --> 28° en Regates intentados [42]
# --> 28° en Entradas [63]
# --> 25° en Porc. Tiros dentro del área [0.47]
# --> 27° en Fueras de juego Rival [2]
# --> 25° en Pases largos efectivos Rival [123]
# --> 25° en Regates completados Rival [35]
# --> 28° en Regates intentados Rival [64]
# --> 28° en Entradas Rival [60]
# --> 25° en Porc. Tiros dentro del área Rival [0.5]
# --> 24° en Goles x Tiros totales Rival [0.06]
# ---------------------Fin equipo------------------------------------
# Talleres
#
# --> 24° en Tiros totales [49]
# --> 24° en Tiros a puerta [14]
# --> 26° en Tiros fuera [18]
# --> 26° en Fueras de juego [6]
# --> 26° en Ocasiones claras [3]
# --> 26° en Ocasiones claras falladas [2]
# --> 26° en Tiros desde fuera del área [17]
# --> 24° en Entradas [74]
# --> 26° en Despejes [60]
# --> 26° en Porc. Tiros fuera del área [0.35]
# --> 26° en Disparos al palo Rival [0]
# --> 26° en Pases largos efectivos Rival [121]
# --> 24° en Porc. Pases largos efectivos Rival [0.39]
# --> 24° en Regates intentados Rival [71]
# --> 24° en Despejes Rival [71]
# --> 24° en Goles Rival [4]
# --> 26° en Goles [2]
# --> 26° en Goles x Tiros totales [0.04]
# --> 26° en Goles x Tiros a puerta [0.14]
# ---------------------Fin equipo------------------------------------
# Tigre
#
# --> 26° en Saques de esquina [19]
# --> 27° en Tarjetas amarillas [9]
# --> 28° en Disparos al palo [0]
# --> 25° en Paradas [10]
# --> 26° en Centros intentados [83]
# --> 26° en Tiros totales Rival [46]
# --> 27° en Tiros a puerta Rival [12]
# --> 25° en Disparos bloqueados Rival [9]
# --> 24° en Faltas Rival [60]
# --> 27° en Contraataques Rival [0]
# --> 26° en Tiros en contraataque Rival [0]
# --> 27° en Tiros dentro del área Rival [26]
# --> 25° en Tiros desde fuera del área Rival [20]
# --> 26° en Balones aéreos ganados Rival [68]
# --> 25° en Despejes Rival [71]
# --> 27° en Goles Rival [2]
# --> 24° en Goles x Tiros totales [0.05]
# --> 26° en Goles x Tiros totales Rival [0.04]
# --> 27° en Goles x Tiros a puerta Rival [0.17]
# ---------------------Fin equipo------------------------------------
# Union
#
# --> 24° en Posesión de balón [43.8]
# --> 24° en Disparos bloqueados [11]
# --> 28° en Fueras de juego [3]
# --> 24° en Tarjetas amarillas [10]
# --> 27° en Contraataques [0]
# --> 27° en Tiros en contraataque [0]
# --> 24° en Tiros desde fuera del área [19]
# --> 24° en Pases totales [1568]
# --> 24° en Pases acertados [1069]
# --> 24° en Porc. Pases efectivos [0.68]
# --> 25° en Centros completados [18]
# --> 25° en Entradas [74]
# --> 25° en Pases por cada perdida [1.91]
# --> 25° en Porc. Tiros fuera del área [0.36]
# --> 28° en Tiros fuera Rival [18]
# --> 27° en Ocasiones claras Rival [3]
# --> 24° en Tiros desde fuera del área Rival [22]
# --> 26° en Regates completados Rival [35]
# --> 27° en Regates intentados Rival [66]
# --> 28° en Goles Rival [2]
# --> 28° en Goles x Tiros totales Rival [0.04]
# --> 28° en Goles x Tiros a puerta Rival [0.11]
# ---------------------Fin equipo------------------------------------
# Velez Sarsfield
#
# --> 28° en Disparos bloqueados [9]
# --> 27° en Ocasiones claras [3]
# --> 28° en Ocasiones claras falladas [1]
# --> 28° en Contraataques [0]
# --> 28° en Tiros en contraataque [0]
# --> 28° en Goles en contraataque [0]
# --> 27° en Pases largos totales [271]
# --> 24° en Centros completados [19]
# --> 24° en Posesión perdida [733]
# --> 24° en Tiros a puerta Rival [16]
# --> 26° en Fueras de juego Rival [4]
# --> 28° en Ocasiones claras Rival [3]
# --> 26° en Ocasiones claras falladas Rival [2]
# --> 28° en Disparos al palo Rival [0]
# --> 28° en Goles en contraataque Rival [0]
# --> 26° en Centros completados Rival [18]
# --> 25° en Duelos ganados Rival [261]
# --> 25° en Goles [3]
# --> 25° en Goles x Tiros a puerta [0.15]
# ---------------------Fin equipo------------------------------------

# %%
# Borrador en proceso de construcción - Separación de métricas positivas y negativas en dos tablas.
lista=['Goles', 'Asistencias','Pases acertados', 'Porc Efectividad pases','Duelos ganados','Duelos en el suelo ganados',
 'Duelos aereos ganados', 'Tiros a puerta','Regates completados',
 'Pases clave', 'Centros completados',  'Recibió falta']
listanegativa=[ 'Fueras de juego', 'Regateado', 'Tiros fuera','Posesion perdida']
Listado=[]
ListadoN=[]
Atributos=[]
atr=[1]

for a in GLOBAL.keys():
    l=list(GLOBAL.sort_values(by=a,ascending=False).head(5).index)
    Listado=Listado+l

for a in GLOBAL.keys():
    l=list(GLOBAL.sort_values(by=a,ascending=False).head(5).index)
    ListadoN=ListadoN+l

#print(Listado)
df=pd.DataFrame(columns=['Jugador','Cantidad'])
dfN=pd.DataFrame(columns=['JugadorN','CantidadN'])
df['Jugador']=Listado
df['Cantidad']=1
dfN['JugadorN']=ListadoN
dfN['CantidadN']=-1
print(df.groupby('Jugador').sum().sort_values(by='Cantidad',ascending=False).head(20))
print(dfN.groupby('JugadorN').sum().sort_values(by='CantidadN',ascending=True).head(20))
#GLOBAL.loc[GLOBAL['Nombre']==df.groupby('Jugador').sum().sort_values(by='Cantidad',ascending=False).index[0]]

for b in range(0,5) :
    for a in GLOBAL.keys():
        l=list(GLOBAL.sort_values(by=a,ascending=False).head(5).index)
        if df.groupby('Jugador').sum().sort_values(by='Cantidad',ascending=False).index[b] in l:
            atr[0]=a
            Atributos=Atributos+atr
    print(df.groupby('Jugador').sum().sort_values(by='Cantidad',ascending=False).index[b]+' '+ str(Atributos))
    print(' ')
    Atributos=[]
# Out:
#                  Cantidad
# Jugador
# Def. y Justicia        26
# Godoy Cruz             24
# San Lorenzo            22
# River                  21
# Barracas Ctral.        20
# Sarmiento              20
# Aldosivi               19
# Tigre                  19
# Newell´s               19
# Arsenal                18
# Gimnasia LP            18
# Colon                  17
# Central CBA            17
# Patronato              16
# Racing Club            16
# Argentinos Jrs         15
# Banfield               15
# Estudiantes LP         14
# Lanus                  14
# CA Huracan             13
#                  CantidadN
# JugadorN
# Def. y Justicia        -26
# Godoy Cruz             -24
# San Lorenzo            -22
# River                  -21
# Sarmiento              -20
# Barracas Ctral.        -20
# Tigre                  -19
# Newell´s               -19
# Aldosivi               -19
# Gimnasia LP            -18
# Arsenal                -18
# Colon                  -17
# Central CBA            -17
# Patronato              -16
# Racing Club            -16
# Argentinos Jrs         -15
# Banfield               -15
# Estudiantes LP         -14
# Lanus                  -14
# CA Huracan             -13
# Def. y Justicia ['Tiros a puerta', 'Tarjetas rojas', 'Pases totales', 'Pases acertados', 'Porc. Pases efectivos', 'Regates completados', 'Porc. Regates efectivos', 'Despejes', 'Porc. Tiros a puerta', 'Pases por cada perdida', 'Tiros totales Rival', 'Tiros a puerta Rival', 'Disparos bloqueados Rival', 'Saques de esquina Rival', 'Fueras de juego Rival', 'Tiros desde fuera del área Rival', 'Porc. Pases largos efectivos Rival', 'Centros completados Rival', 'Centros intentados Rival', 'Regates completados Rival', 'Regates intentados Rival', 'Porc. Regates efectivos Rival', 'Porc. Tiros fuera del área Rival', 'Goles', 'Goles x Tiros totales', 'Goles x Tiros a puerta']
#
# Godoy Cruz ['Tiros totales', 'Tiros fuera', 'Saques de esquina', 'Tarjetas rojas', 'Ocasiones claras', 'Contraataques', 'Tiros en contraataque', 'Goles en contraataque', 'Tiros dentro del área', 'Pases largos efectivos', 'Porc. Pases largos efectivos', 'Centros completados', 'Regates completados', 'Regates intentados', 'Porc. Regates efectivos', 'Disparos al palo Rival', 'Porc. Centros completados Rival', 'Regates completados Rival', 'Regates intentados Rival', 'Entradas Rival', 'Despejes Rival', 'Goles Rival', 'Goles x Tiros totales Rival', 'Goles x Tiros a puerta Rival']
#
# San Lorenzo ['Fueras de juego', 'Paradas', 'Regates intentados', 'Duelos ganados', 'Entradas', 'Porc. Tiros fuera del área', 'Posesión de balón Rival', 'Tiros totales Rival', 'Tiros a puerta Rival', 'Saques de esquina Rival', 'Faltas Rival', 'Ocasiones claras falladas Rival', 'Tiros dentro del área Rival', 'Tiros desde fuera del área Rival', 'Pases totales Rival', 'Pases acertados Rival', 'Porc. Pases efectivos Rival', 'Centros completados Rival', 'Duelos ganados Rival', 'Entradas Rival', 'Porc. Tiros a puerta Rival', 'Pases por cada perdida Rival']
#
# River ['Posesión de balón', 'Tiros a puerta', 'Saques de esquina', 'Ocasiones claras', 'Ocasiones claras falladas', 'Disparos al palo', 'Pases totales', 'Pases acertados', 'Porc. Pases efectivos', 'Pases largos efectivos', 'Porc. Pases largos efectivos', 'Posesión perdida', 'Porc. Tiros a puerta', 'Pases por cada perdida', 'Porc. Tiros dentro del área', 'Centros completados Rival', 'Posesión perdida Rival', 'Intercepciones Rival', 'Porc. Tiros dentro del área Rival', 'Goles', 'Goles x Tiros totales']
#
# Barracas Ctral. ['Paradas', 'Porc. Tiros a puerta', 'Posesión de balón Rival', 'Tiros totales Rival', 'Tiros a puerta Rival', 'Disparos bloqueados Rival', 'Fueras de juego Rival', 'Ocasiones claras Rival', 'Ocasiones claras falladas Rival', 'Contraataques Rival', 'Tiros en contraataque Rival', 'Goles en contraataque Rival', 'Tiros dentro del área Rival', 'Pases acertados Rival', 'Porc. Pases efectivos Rival', 'Pases largos efectivos Rival', 'Porc. Pases largos efectivos Rival', 'Porc. Tiros a puerta Rival', 'Porc. Tiros dentro del área Rival', 'Goles Rival']
