# %%
# Este es un análisis de jugadores destacados por ROL (DEFENSOR-MEDIO DEFENSIVO- MEDIO OFENSIVO- MEDIO GRAL- DELANTERO)
# Carga de tablas y creacion de columnas. Hay tablas que se encuentran agregadas para futuros cruces de información.

import warnings
warnings.filterwarnings("ignore")
import pandas as pd

BIGDATA=pd.read_excel('Jugadores-CopaBinance2022.xlsx',sheet_name='BIGDATA',index_col='Nombre')
GLOBAL=pd.read_excel('Equipos-CopaBinance2022.xlsx',sheet_name='GLOBAL',index_col='Unnamed: 0').T
Tiempo1=pd.read_excel('Equipos-CopaBinance2022.xlsx',sheet_name='1TIEMPO',index_col='Unnamed: 0').T
Tiempo2=pd.read_excel('Equipos-CopaBinance2022.xlsx',sheet_name='2TIEMPO',index_col='Unnamed: 0').T
GLOBAL = GLOBAL[GLOBAL['Regates'].notna()]
Vacios = GLOBAL[ GLOBAL['Posesión de balón'] == ' ' ].index
GLOBAL.drop(Vacios , inplace=True)
Tiempo1 = Tiempo1[Tiempo1['Regates'].notna()]
Vacios = Tiempo1[ Tiempo1['Posesión de balón'] == ' ' ].index
Tiempo1.drop(Vacios , inplace=True)
Tiempo2 = Tiempo2[Tiempo2['Regates'].notna()]
Vacios = Tiempo2[ Tiempo2['Posesión de balón'] == ' ' ].index
Tiempo2.drop(Vacios , inplace=True)
#### Agregado de Rival-Resultado-Condicion a BIGDATA
Fixture=pd.read_excel('ResultadosCopaBinance2022.xlsx')
ContadorFixture=0
inicio=0
BIGDATA['Resultado']=""
BIGDATA['Rival']=''
BIGDATA['Condicion']=''
BIGDATA['Local']=''
BIGDATA['Visitante']=''
BIGDATA['Partido']=''
for i in range(0,len(BIGDATA.index)):
    if BIGDATA['Equipo'].iloc[i]==Fixture['Local'][ContadorFixture]:
        BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
        BIGDATA['Condicion'][i]='Home'
        BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
        BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
        BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]
    elif BIGDATA['Equipo'].iloc[i]==Fixture['Visitante'][ContadorFixture]:
        BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
        BIGDATA['Condicion'][i]='Away'
        BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
        BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
        BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
    else:
        for a in range(inicio,i):
            BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]      
        inicio=i
        ContadorFixture=ContadorFixture+1
        if BIGDATA['Equipo'].iloc[i]==Fixture['Local'][ContadorFixture]:
            BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
            BIGDATA['Condicion'][i]='Home'
            BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
            BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
            BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]   
        else:
            BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
            BIGDATA['Condicion'][i]='Away'
            BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
            BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
            BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
for a in range(inicio,i+1):
    BIGDATA['Resultado'][a]=BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]   
####
BIGDATA.insert(loc = 4, column = 'Goles y Asistencias', value = BIGDATA['Goles']+BIGDATA['Asistencias'])
### Numerizando GLOBAL
GLOBAL['Posesión de balón']=GLOBAL['Posesión de balón'].astype('float64')*100
GLOBAL[['Tiros totales', 'Tiros a puerta', 'Tiros fuera','Disparos bloqueados', 'Saques de esquina', 'Fueras de juego',
        'Faltas','Tarjetas amarillas', 'Tarjetas rojas', 'Ocasiones claras','Ocasiones claras falladas', 'Disparos al Palo',
        'Contraataques','Tiros en contraataque', 'Goles en contraataque','Tiros dentro del área',
        'Tiros desde fuera del área', 'Paradas','Pases', 'Pases totales', 'Porc. Pases efectivos','Pases largos efectivos',
        'Pases largos totales','Porc. Pases largos efectivos', 'Centros completados','Centros intentados',
        'Porc. Centros completados','Regates completados', 'Regates intentados', 'Porc. Regates efectivos','Posesión perdida',
        'Duelos ganados', 'Balones aéreos ganados','Entradas', 'Intercepciones', 'Despejes']]=GLOBAL[['Tiros totales', 'Tiros a puerta', 'Tiros fuera',
       'Disparos bloqueados', 'Saques de esquina', 'Fueras de juego', 'Faltas','Tarjetas amarillas', 'Tarjetas rojas','Ocasiones claras',
       'Ocasiones claras falladas', 'Disparos al Palo', 'Contraataques','Tiros en contraataque', 'Goles en contraataque',
       'Tiros dentro del área', 'Tiros desde fuera del área', 'Paradas','Pases', 'Pases totales', 'Porc. Pases efectivos',
       'Pases largos efectivos', 'Pases largos totales','Porc. Pases largos efectivos', 'Centros completados',
       'Centros intentados', 'Porc. Centros completados','Regates completados', 'Regates intentados', 'Porc. Regates efectivos',
       'Posesión perdida', 'Duelos ganados', 'Balones aéreos ganados','Entradas', 'Intercepciones', 'Despejes']].astype('int64')
####
pd.options.display.max_columns = None

# %%
# 2° Cambio de medias de algunos parámetros de este torneo (analizados en la temporada anterior)
BIGDATA['Porc Efectividad pases']=BIGDATA['Porc Efectividad pases']*(BIGDATA['Minutos jugados']/90)
listas=['Goles','Asistencias','Entradas','Goles y Asistencias','Pases acertados','Pases totales','Porc Efectividad pases',
        'Duelos ganados','Duelos en el suelo ganados','Duelos aereos ganados','Tiros a puerta','Tiros fuera',
        'Regates completados','Despejes','Disparos Bloq Def','Intercepciones','Regateado','Pases clave','Posesion perdida',
        'Faltas','Recibió falta','Fueras de juego']
lis=[1.02,0.52,5.63,1.36,68.38,76.92,0.9,11.66,9.15,5.88,1.92,1.78,5.07,5.54,0.82,2.9,2.93,3.01,24.24,3.46,4.37,1.23]

c=BIGDATA.max()
for k,o in zip(listas,lis):
    c[k]=o

# %%
# 3° Análisis, no hay visualización, solo Output.
variables=['Goles','Asistencias','Entradas','Goles y Asistencias','Pases acertados','Pases totales','Porc Efectividad pases',
       'Duelos efectuados','Duelos ganados','Duelos en el suelo efectuados','Duelos en el suelo ganados',
       'Duelos aéreos efectuados','Duelos aereos ganados','Tiros a puerta','Tiros fuera','Disparos bloq ATA',
       'Regates intentados','Regates completados','Despejes','Disparos Bloq Def','Intercepciones','Entradas.1',
       'Regateado','Toques','Pases clave','Centros intentados','Centros completados','Balones largos intentados',
       'Balones largos completados','Posesion perdida','Faltas','Recibió falta','Fueras de juego']
defensor=['Pases totales','Porc Efectividad pases','Duelos efectuados','Duelos en el suelo efectuados',
          'Duelos aéreos efectuados','Balones largos intentados','Pases acertados','Duelos ganados',
          'Duelos en el suelo ganados','Balones largos completados','Duelos aereos ganados','Entradas','Despejes',
          'Disparos Bloq Def','Intercepciones','Toques','Regateado','Faltas']
medio=['Duelos en el suelo efectuados','Pases totales','Porc Efectividad pases','Duelos efectuados',
       'Duelos aéreos efectuados','Regates intentados','Balones largos intentados','Centros intentados','Duelos ganados',
       'Duelos en el suelo ganados','Centros completados','Balones largos completados','Duelos aereos ganados',
       'Regates completados','Pases acertados','Goles','Asistencias','Entradas','Tiros a puerta','Disparos bloq ATA',
       'Despejes','Disparos Bloq Def','Intercepciones','Toques','Pases clave','Recibió falta','Regateado','Tiros fuera',
       'Posesion perdida','Faltas','Fueras de juego']
delantero=['Duelos aéreos efectuados','Regates intentados','Porc Efectividad pases','Regates completados',
           'Duelos aereos ganados','Tiros a puerta','Goles','Asistencias','Pases clave','Recibió falta','Tiros fuera',
           'Posesion perdida','Fueras de juego']
#eleccion=input('Opciones - defensor, medio, medio defensivo, medio ofensivo, delantero - : ')
eleccion=['defensor','medio','medio defensivo','medio ofensivo','ofensivo','global']
for x in eleccion:
    if x=='defensor':
        lista=defensor
        BIGG=BIGDATA.loc[BIGDATA['Posicion']=="D"]
    elif x=='medio':
        lista=medio
        BIGG=BIGDATA.loc[BIGDATA['Posicion']=="M"]
    elif x=='global':
        lista=medio
        BIGG=BIGDATA
    elif x=='medio ofensivo':
        lista=delantero
        BIGG=BIGDATA.loc[BIGDATA['Posicion']=="M"]
    elif x=='medio defensivo':
        lista=defensor
        BIGG=BIGDATA.loc[BIGDATA['Posicion']=="M"]
    else:
        lista=delantero
        BIGG=BIGDATA.loc[BIGDATA['Posicion']=="F"]
    BIG=BIGG.groupby('Nombre').sum()
    for a in variables:
        BIG[a]=(BIG[a]/c[a])/(BIG['Minutos jugados']/90)
    BIG.sort_values(by='Nombre')
    #otra celda
    #lista=['Goles y Asistencias','Pases totales','Porc Efectividad pases','Duelos efectuados','Duelos en el suelo efectuados',
           #'Duelos aéreos efectuados','Regates intentados','Balones largos intentados','Centros intentados','Goles',
           #'Asistencias','Pases acertados','Duelos ganados','Duelos en el suelo ganados','Centros completados',
           #'Balones largos completados','Duelos aereos ganados','Regates completados','Entradas',
           #'Tiros a puerta','Disparos bloq ATA','Despejes','Disparos Bloq Def','Intercepciones','Toques',
           #'Pases clave','Recibió falta','Regateado','Tiros fuera',
           #'Posesion perdida','Faltas','Fueras de juego']
    ORDEN=BIG.loc[BIG['Minutos jugados']>BIG['Minutos jugados'].max()*0.4]
    nombre=[]
    posicion=[]
    atributo=[]
    valor=[]
    #'Goles y Asistencias''Regates intentados''Duelos ganados'
    for m in lista:
        ORDEN=ORDEN.sort_values(by=m,ascending=False)
        for p in range(1,11):
            nombre.append(ORDEN.index[p-1])
            posicion.append(p-1)
            atributo.append(m)
            valor.append(ORDEN[m][p-1])
            #print(ORDEN.index[p])
            #print(p)       
    MP=pd.DataFrame(columns=['Nombre','Posicion','Atributo','Valor'])
    MP['Nombre']=nombre
    MP['Posicion']=posicion
    MP['Atributo']=atributo
    MP['Valor']=valor
    #ELECCION DE ANALISIS
    if x=='defensor':
        for i in range(0,60):
            MP['Valor'][i]=MP['Valor'][i]*0.2
        for i in range(60,110):
            MP['Valor'][i]=MP['Valor'][i]*0.8
        for i in range(160,len(MP.index)):
            MP['Valor'][i]=MP['Valor'][i]*-1
    elif x=='medio':
        for i in range(0,80):
            MP['Valor'][i]=MP['Valor'][i]*0.2
        for i in range(80,150):
            MP['Valor'][i]=MP['Valor'][i]*0.8
        for i in range(250,len(MP.index)):
            MP['Valor'][i]=MP['Valor'][i]*-1
    elif x=='global':
        for i in range(0,80):
            MP['Valor'][i]=MP['Valor'][i]*0.2
        for i in range(80,150):
            MP['Valor'][i]=MP['Valor'][i]*0.8
        for i in range(250,len(MP.index)):
            MP['Valor'][i]=MP['Valor'][i]*-1
    elif x=='medio defensivo':
        for i in range(0,60):
            MP['Valor'][i]=MP['Valor'][i]*0.2
        for i in range(60,110):
            MP['Valor'][i]=MP['Valor'][i]*0.8
        for i in range(160,len(MP.index)):
            MP['Valor'][i]=MP['Valor'][i]*-1
    else:
        for i in range(0,30):
            MP['Valor'][i]=MP['Valor'][i]*0.2
        for i in range(30,50):
            MP['Valor'][i]=MP['Valor'][i]*0.8
        for i in range(100,len(MP.index)):
            MP['Valor'][i]=MP['Valor'][i]*-1
    # ACA ESTA EL LISTADO
    Mejores=list(MP.groupby('Nombre').sum().sort_values(by='Valor',ascending=False).head(20).index)
    print('################################################################################')
    print('Aqui se encuentra el informe para jugadores categorizado en forma '+ x)
    print('################################################################################')
    for a in Mejores:    
        print(MP.loc[MP['Nombre']==a])
# Out:
# ################################################################################
# Aqui se encuentra el informe para jugadores categorizado en forma defensor
# ################################################################################
#                Nombre  Posicion                   Atributo     Valor
# 5    Nazareno Colombo         5              Pases totales  0.173698
# 41   Nazareno Colombo         1   Duelos aéreos efectuados  0.083687
# 54   Nazareno Colombo         4  Balones largos intentados  0.078573
# 68   Nazareno Colombo         8            Pases acertados  0.578936
# 101  Nazareno Colombo         1      Duelos aereos ganados  0.673259
# 121  Nazareno Colombo         1                   Despejes  1.451487
# 155  Nazareno Colombo         5                     Toques  0.694609
#                     Nombre  Posicion                    Atributo     Valor
# 2    Christian Javier Báez         2               Pases totales  0.186317
# 51   Christian Javier Báez         1   Balones largos intentados  0.089894
# 63   Christian Javier Báez         3             Pases acertados  0.678116
# 90   Christian Javier Báez         0  Balones largos completados  0.525815
# 142  Christian Javier Báez         2              Intercepciones  1.349325
# 154  Christian Javier Báez         4                      Toques  0.705631
#                    Nombre  Posicion               Atributo     Valor
# 109  Matías de los Santos         9  Duelos aereos ganados  0.500928
# 139  Matías de los Santos         9      Disparos Bloq Def  1.496674
# 141  Matías de los Santos         1         Intercepciones  1.410658
#          Nombre  Posicion                    Atributo     Valor
# 1    Paulo Díaz         1               Pases totales  0.193075
# 21   Paulo Díaz         1           Duelos efectuados  0.108455
# 40   Paulo Díaz         0    Duelos aéreos efectuados  0.092608
# 52   Paulo Díaz         2   Balones largos intentados  0.086518
# 61   Paulo Díaz         1             Pases acertados  0.712192
# 71   Paulo Díaz         1              Duelos ganados  0.648100
# 91   Paulo Díaz         1  Balones largos completados  0.498542
# 100  Paulo Díaz         0       Duelos aereos ganados  0.821086
# 152  Paulo Díaz         2                      Toques  0.746308
# 178  Paulo Díaz         8                      Faltas -0.682519
#              Nombre  Posicion                    Atributo     Valor
# 3    Lucas Villalba         3               Pases totales  0.183749
# 65   Lucas Villalba         5             Pases acertados  0.658999
# 99   Lucas Villalba         9  Balones largos completados  0.301386
# 145  Lucas Villalba         5              Intercepciones  1.146771
# 151  Lucas Villalba         1                      Toques  0.758149
#                Nombre  Posicion           Atributo     Valor
# 133  Nicolás Ferreyra         3  Disparos Bloq Def  1.829268
# 147  Nicolás Ferreyra         7     Intercepciones  1.120690
#                Nombre  Posicion           Atributo     Valor
# 124  Ignacio Gariglio         4           Despejes  1.193171
# 138  Ignacio Gariglio         8  Disparos Bloq Def  1.550227
#              Nombre  Posicion                Atributo     Valor
# 17   Sergio Barreto         7  Porc Efectividad pases  0.192333
# 103  Sergio Barreto         3   Duelos aereos ganados  0.571429
# 134  Sergio Barreto         4       Disparos Bloq Def  1.829268
#              Nombre  Posicion                    Atributo     Valor
# 0    Davíd Martínez         0               Pases totales  0.230517
# 16   Davíd Martínez         6      Porc Efectividad pases  0.192371
# 60   Davíd Martínez         0             Pases acertados  0.890546
# 98   Davíd Martínez         8  Balones largos completados  0.313433
# 106  Davíd Martínez         6       Duelos aereos ganados  0.548279
# 150  Davíd Martínez         0                      Toques  0.818449
# 168  Davíd Martínez         8                   Regateado -0.458459
#                Nombre  Posicion           Atributo     Valor
# 110  Gianluca Ferrari         0           Entradas  0.817052
# 136  Gianluca Ferrari         6  Disparos Bloq Def  1.707317
#                Nombre  Posicion                Atributo     Valor
# 19   Leonardo Morales         9  Porc Efectividad pases  0.185778
# 131  Leonardo Morales         1       Disparos Bloq Def  1.951220
#             Nombre  Posicion                       Atributo     Valor
# 24   Gonzalo Piovi         4              Duelos efectuados  0.089333
# 36   Gonzalo Piovi         6  Duelos en el suelo efectuados  0.074074
# 78   Gonzalo Piovi         8                 Duelos ganados  0.548885
# 88   Gonzalo Piovi         8     Duelos en el suelo ganados  0.489617
# 112  Gonzalo Piovi         2                       Entradas  0.746004
# 158  Gonzalo Piovi         8                         Toques  0.662295
# 166  Gonzalo Piovi         6                      Regateado -0.477816
#            Nombre  Posicion                    Atributo     Valor
# 4    Adonis Frías         4               Pases totales  0.177847
# 10   Adonis Frías         0      Porc Efectividad pases  0.196889
# 62   Adonis Frías         2             Pases acertados  0.711319
# 96   Adonis Frías         6  Balones largos completados  0.360000
# 157  Adonis Frías         7                      Toques  0.670492
#                  Nombre  Posicion           Atributo    Valor
# 130  Haibrany Ruiz Diaz         0  Disparos Bloq Def  1.95122
#            Nombre  Posicion           Atributo     Valor
# 132  Lucas Suarez         2  Disparos Bloq Def  1.948333
#               Nombre  Posicion                  Atributo     Valor
# 29   Leonel Mosevich         9         Duelos efectuados  0.085714
# 47   Leonel Mosevich         7  Duelos aéreos efectuados  0.070588
# 76   Leonel Mosevich         6            Duelos ganados  0.568488
# 107  Leonel Mosevich         7     Duelos aereos ganados  0.544218
# 119  Leonel Mosevich         9                  Entradas  0.608982
#             Nombre  Posicion        Atributo     Valor
# 116  Rufino Lucero         6        Entradas  0.639432
# 146  Rufino Lucero         6  Intercepciones  1.145889
#            Nombre  Posicion           Atributo     Valor
# 135  Rafael Pérez         5  Disparos Bloq Def  1.714939
#                Nombre  Posicion           Atributo     Valor
# 137  Federico Andueza         7  Disparos Bloq Def  1.707317
#           Nombre  Posicion  Atributo     Valor
# 120  Gastón Suso         0  Despejes  1.682568
# ################################################################################
# Aqui se encuentra el informe para jugadores categorizado en forma medio
# ################################################################################
#          Nombre  Posicion                    Atributo     Valor
# 10   Enzo Pérez         0               Pases totales  0.181313
# 44   Enzo Pérez         4    Duelos aéreos efectuados  0.068702
# 114  Enzo Pérez         4  Balones largos completados  0.240458
# 140  Enzo Pérez         0             Pases acertados  0.679186
# 179  Enzo Pérez         9                    Entradas  0.610145
# 205  Enzo Pérez         5                    Despejes  0.620057
# 223  Enzo Pérez         3              Intercepciones  0.829166
# 230  Enzo Pérez         0                      Toques  0.689839
#                  Nombre  Posicion               Atributo     Valor
# 83   Sebastian Prediger         3         Duelos ganados  0.664726
# 129  Sebastian Prediger         9  Duelos aereos ganados  0.381569
# 177  Sebastian Prediger         7               Entradas  0.633997
# 201  Sebastian Prediger         1               Despejes  0.782361
# 226  Sebastian Prediger         6         Intercepciones  0.791247
#          Nombre  Posicion                       Atributo     Valor
# 2    Ivan Gómez         2  Duelos en el suelo efectuados  0.115016
# 32   Ivan Gómez         2              Duelos efectuados  0.118850
# 82   Ivan Gómez         2                 Duelos ganados  0.690490
# 90   Ivan Gómez         0     Duelos en el suelo ganados  0.829623
# 151  Ivan Gómez         1                          Goles  0.563804
# 172  Ivan Gómez         2                       Entradas  0.817165
#              Nombre  Posicion                       Atributo     Valor
# 7    Carlos Rotondi         7  Duelos en el suelo efectuados  0.098837
# 97   Carlos Rotondi         7     Duelos en el suelo ganados  0.640488
# 152  Carlos Rotondi         2                          Goles  0.512996
# 164  Carlos Rotondi         4                    Asistencias  1.006261
# 174  Carlos Rotondi         4                       Entradas  0.697055
#           Nombre  Posicion                    Atributo     Valor
# 58   Enzo Roldán         8          Regates intentados  0.086631
# 81   Enzo Roldán         1              Duelos ganados  0.693444
# 92   Enzo Roldán         2  Duelos en el suelo ganados  0.799509
# 131  Enzo Roldán         1         Regates completados  0.531595
# 155  Enzo Roldán         5                       Goles  0.471846
# 212  Enzo Roldán         2           Disparos Bloq Def  1.173862
# 251  Enzo Roldán         1               Recibió falta -0.991202
#              Nombre  Posicion                    Atributo     Valor
# 11   Enzo Fernández         1               Pases totales  0.175642
# 117  Enzo Fernández         7  Balones largos completados  0.218245
# 143  Enzo Fernández         3             Pases acertados  0.632250
# 166  Enzo Fernández         6                 Asistencias  0.799432
# 231  Enzo Fernández         1                      Toques  0.679779
# 241  Enzo Fernández         1                 Pases clave  1.035808
# 276  Enzo Fernández         6                 Tiros fuera -0.817396
#              Nombre  Posicion           Atributo     Valor
# 12   Tomás Belmonte         2      Pases totales  0.173687
# 141  Tomás Belmonte         1    Pases acertados  0.659842
# 211  Tomás Belmonte         1  Disparos Bloq Def  1.219512
# 232  Tomás Belmonte         2             Toques  0.670492
#           Nombre  Posicion                Atributo     Valor
# 13   Fausto Vera         3           Pases totales  0.162767
# 23   Fausto Vera         3  Porc Efectividad pases  0.199111
# 142  Fausto Vera         2         Pases acertados  0.655162
# 219  Fausto Vera         9       Disparos Bloq Def  0.975610
# 233  Fausto Vera         3                  Toques  0.627869
#                Nombre  Posicion             Atributo     Valor
# 77   Franco Cristaldo         7   Centros intentados  0.081522
# 109  Franco Cristaldo         9  Centros completados  0.208696
# 161  Franco Cristaldo         1          Asistencias  1.505017
# 245  Franco Cristaldo         5          Pases clave  0.780009
#              Nombre  Posicion                Atributo     Valor
# 18   Bruno Zuculini         8           Pases totales  0.138165
# 22   Bruno Zuculini         2  Porc Efectividad pases  0.199858
# 127  Bruno Zuculini         7   Duelos aereos ganados  0.390795
# 148  Bruno Zuculini         8         Pases acertados  0.554473
# 213  Bruno Zuculini         3       Disparos Bloq Def  1.167618
#                 Nombre  Posicion                       Atributo     Valor
# 0    Ignacio Fernandez         0  Duelos en el suelo efectuados  0.121212
# 31   Ignacio Fernandez         1              Duelos efectuados  0.122078
# 52   Ignacio Fernandez         2             Regates intentados  0.101299
# 80   Ignacio Fernandez         0                 Duelos ganados  0.721748
# 91   Ignacio Fernandez         1     Duelos en el suelo ganados  0.817543
# 130  Ignacio Fernandez         0            Regates completados  0.614770
# 235  Ignacio Fernandez         5                         Toques  0.613157
# 296  Ignacio Fernandez         6                         Faltas -0.900833
#                 Nombre  Posicion        Atributo     Valor
# 88   Nicolás Garayalde         8  Duelos ganados  0.588892
# 171  Nicolás Garayalde         1        Entradas  0.827602
# 229  Nicolás Garayalde         9  Intercepciones  0.761064
#               Nombre  Posicion                    Atributo     Valor
# 43   Fernando Juarez         3    Duelos aéreos efectuados  0.070105
# 64   Fernando Juarez         4   Balones largos intentados  0.047760
# 115  Fernando Juarez         5  Balones largos completados  0.236301
# 121  Fernando Juarez         1       Duelos aereos ganados  0.615041
# 221  Fernando Juarez         1              Intercepciones  1.204535
#                 Nombre  Posicion                       Atributo     Valor
# 5    Agustín Martegani         5  Duelos en el suelo efectuados  0.108466
# 38   Agustín Martegani         8              Duelos efectuados  0.107143
# 59   Agustín Martegani         9             Regates intentados  0.085714
# 96   Agustín Martegani         6     Duelos en el suelo ganados  0.655738
# 133  Agustín Martegani         3            Regates completados  0.507185
# 162  Agustín Martegani         2                    Asistencias  1.373626
# 258  Agustín Martegani         8                  Recibió falta -0.735534
#                Nombre  Posicion                    Atributo     Valor
# 67   Rodrigo Villagra         7   Balones largos intentados  0.045018
# 86   Rodrigo Villagra         6              Duelos ganados  0.608279
# 93   Rodrigo Villagra         3  Duelos en el suelo ganados  0.704673
# 112  Rodrigo Villagra         2  Balones largos completados  0.255224
# 134  Rodrigo Villagra         4         Regates completados  0.466308
#                Nombre  Posicion                    Atributo     Valor
# 17   Federico Fattori         7               Pases totales  0.141909
# 20   Federico Fattori         0      Porc Efectividad pases  0.202463
# 62   Federico Fattori         2   Balones largos intentados  0.048844
# 110  Federico Fattori         0  Balones largos completados  0.379518
# 145  Federico Fattori         5             Pases acertados  0.583557
# 202  Federico Fattori         2                    Despejes  0.717672
#                        Nombre  Posicion                       Atributo  \
# 4    Nicolás Fernández Mercau         4  Duelos en el suelo efectuados
# 37   Nicolás Fernández Mercau         7              Duelos efectuados
# 54   Nicolás Fernández Mercau         4             Regates intentados
# 89   Nicolás Fernández Mercau         9                 Duelos ganados
# 94   Nicolás Fernández Mercau         4     Duelos en el suelo ganados
# 135  Nicolás Fernández Mercau         5            Regates completados
#
#         Valor
# 4    0.112601
# 37   0.107775
# 54   0.096515
# 89   0.579420
# 94   0.696172
# 135  0.456875
#              Nombre  Posicion             Atributo     Valor
# 71   Brahian Alemán         1   Centros intentados  0.127784
# 101  Brahian Alemán         1  Centros completados  0.280624
# 158  Brahian Alemán         8                Goles  0.393030
# 180  Brahian Alemán         0       Tiros a puerta  1.043987
# 199  Brahian Alemán         9    Disparos bloq ATA  0.334076
# 243  Brahian Alemán         3          Pases clave  0.865711
# 281  Brahian Alemán         1     Posesion perdida -1.008843
#               Nombre  Posicion             Atributo     Valor
# 56   Gastón González         6   Regates intentados  0.095000
# 75   Gastón González         5   Centros intentados  0.093750
# 104  Gastón González         4  Centros completados  0.225000
# 136  Gastón González         6  Regates completados  0.433925
# 240  Gastón González         0          Pases clave  1.162791
#               Nombre  Posicion                    Atributo     Valor
# 61   Hernán Lamberti         1   Balones largos intentados  0.058423
# 119  Hernán Lamberti         9  Balones largos completados  0.207852
# 204  Hernán Lamberti         4                    Despejes  0.637814
# 218  Hernán Lamberti         8           Disparos Bloq Def  1.013913
# ################################################################################
# Aqui se encuentra el informe para jugadores categorizado en forma medio defensivo
# ################################################################################
#          Nombre  Posicion                    Atributo     Valor
# 0    Enzo Pérez         0               Pases totales  0.181313
# 44   Enzo Pérez         4    Duelos aéreos efectuados  0.068702
# 60   Enzo Pérez         0             Pases acertados  0.679186
# 94   Enzo Pérez         4  Balones largos completados  0.240458
# 119  Enzo Pérez         9                    Entradas  0.610145
# 125  Enzo Pérez         5                    Despejes  0.620057
# 143  Enzo Pérez         3              Intercepciones  0.829166
# 150  Enzo Pérez         0                      Toques  0.689839
#                  Nombre  Posicion               Atributo     Valor
# 73   Sebastian Prediger         3         Duelos ganados  0.664726
# 109  Sebastian Prediger         9  Duelos aereos ganados  0.381569
# 117  Sebastian Prediger         7               Entradas  0.633997
# 121  Sebastian Prediger         1               Despejes  0.782361
# 146  Sebastian Prediger         6         Intercepciones  0.791247
#              Nombre  Posicion           Atributo     Valor
# 2    Tomás Belmonte         2      Pases totales  0.173687
# 61   Tomás Belmonte         1    Pases acertados  0.659842
# 131  Tomás Belmonte         1  Disparos Bloq Def  1.219512
# 152  Tomás Belmonte         2             Toques  0.670492
#           Nombre  Posicion                    Atributo     Valor
# 71   Enzo Roldán         1              Duelos ganados  0.693444
# 82   Enzo Roldán         2  Duelos en el suelo ganados  0.799509
# 132  Enzo Roldán         2           Disparos Bloq Def  1.173862
#           Nombre  Posicion                Atributo     Valor
# 3    Fausto Vera         3           Pases totales  0.162767
# 13   Fausto Vera         3  Porc Efectividad pases  0.199111
# 62   Fausto Vera         2         Pases acertados  0.655162
# 139  Fausto Vera         9       Disparos Bloq Def  0.975610
# 153  Fausto Vera         3                  Toques  0.627869
#          Nombre  Posicion                       Atributo     Valor
# 22   Ivan Gómez         2              Duelos efectuados  0.118850
# 32   Ivan Gómez         2  Duelos en el suelo efectuados  0.115016
# 72   Ivan Gómez         2                 Duelos ganados  0.690490
# 80   Ivan Gómez         0     Duelos en el suelo ganados  0.829623
# 112  Ivan Gómez         2                       Entradas  0.817165
#              Nombre  Posicion                Atributo     Valor
# 8    Bruno Zuculini         8           Pases totales  0.138165
# 12   Bruno Zuculini         2  Porc Efectividad pases  0.199858
# 68   Bruno Zuculini         8         Pases acertados  0.554473
# 107  Bruno Zuculini         7   Duelos aereos ganados  0.390795
# 133  Bruno Zuculini         3       Disparos Bloq Def  1.167618
#                 Nombre  Posicion        Atributo     Valor
# 78   Nicolás Garayalde         8  Duelos ganados  0.588892
# 111  Nicolás Garayalde         1        Entradas  0.827602
# 149  Nicolás Garayalde         9  Intercepciones  0.761064
#               Nombre  Posicion                    Atributo     Valor
# 43   Fernando Juarez         3    Duelos aéreos efectuados  0.070105
# 54   Fernando Juarez         4   Balones largos intentados  0.047760
# 95   Fernando Juarez         5  Balones largos completados  0.236301
# 101  Fernando Juarez         1       Duelos aereos ganados  0.615041
# 141  Fernando Juarez         1              Intercepciones  1.204535
#                Nombre  Posicion                    Atributo     Valor
# 7    Federico Fattori         7               Pases totales  0.141909
# 10   Federico Fattori         0      Porc Efectividad pases  0.202463
# 52   Federico Fattori         2   Balones largos intentados  0.048844
# 65   Federico Fattori         5             Pases acertados  0.583557
# 90   Federico Fattori         0  Balones largos completados  0.379518
# 122  Federico Fattori         2                    Despejes  0.717672
#               Nombre  Posicion                    Atributo     Valor
# 51   Hernán Lamberti         1   Balones largos intentados  0.058423
# 99   Hernán Lamberti         9  Balones largos completados  0.207852
# 124  Hernán Lamberti         4                    Despejes  0.637814
# 138  Hernán Lamberti         8           Disparos Bloq Def  1.013913
#            Nombre  Posicion                    Atributo     Valor
# 4    Lucas Romero         4               Pases totales  0.159126
# 50   Lucas Romero         0   Balones largos intentados  0.060541
# 64   Lucas Romero         4             Pases acertados  0.587306
# 91   Lucas Romero         1  Balones largos completados  0.340000
# 154  Lucas Romero         4                      Toques  0.621311
#              Nombre  Posicion                    Atributo     Valor
# 1    Enzo Fernández         1               Pases totales  0.175642
# 63   Enzo Fernández         3             Pases acertados  0.632250
# 97   Enzo Fernández         7  Balones largos completados  0.218245
# 151  Enzo Fernández         1                      Toques  0.679779
#               Nombre  Posicion           Atributo     Valor
# 130  Francisco Grahl         0  Disparos Bloq Def  1.695075
#               Nombre  Posicion                    Atributo     Valor
# 57  Rodrigo Villagra         7   Balones largos intentados  0.045018
# 76  Rodrigo Villagra         6              Duelos ganados  0.608279
# 83  Rodrigo Villagra         3  Duelos en el suelo ganados  0.704673
# 92  Rodrigo Villagra         2  Balones largos completados  0.255224
#               Nombre  Posicion        Atributo     Valor
# 140  Jorge Rodríguez         0  Intercepciones  1.609195
#             Nombre  Posicion           Atributo     Valor
# 127  Juan Portillo         7           Despejes  0.521460
# 135  Juan Portillo         5  Disparos Bloq Def  1.084011
#                       Nombre  Posicion                       Atributo  \
# 27  Nicolás Fernández Mercau         7              Duelos efectuados
# 34  Nicolás Fernández Mercau         4  Duelos en el suelo efectuados
# 79  Nicolás Fernández Mercau         9                 Duelos ganados
# 84  Nicolás Fernández Mercau         4     Duelos en el suelo ganados
#
#        Valor
# 27  0.107775
# 34  0.112601
# 79  0.579420
# 84  0.696172
#                 Nombre  Posicion                       Atributo     Valor
# 21   Ignacio Fernandez         1              Duelos efectuados  0.122078
# 30   Ignacio Fernandez         0  Duelos en el suelo efectuados  0.121212
# 70   Ignacio Fernandez         0                 Duelos ganados  0.721748
# 81   Ignacio Fernandez         1     Duelos en el suelo ganados  0.817543
# 155  Ignacio Fernandez         5                         Toques  0.613157
# 176  Ignacio Fernandez         6                         Faltas -0.900833
#              Nombre  Posicion                       Atributo     Valor
# 37   Carlos Rotondi         7  Duelos en el suelo efectuados  0.098837
# 87   Carlos Rotondi         7     Duelos en el suelo ganados  0.640488
# 114  Carlos Rotondi         4                       Entradas  0.697055
# ################################################################################
# Aqui se encuentra el informe para jugadores categorizado en forma medio ofensivo
# ################################################################################
#                Nombre  Posicion             Atributo     Valor
# 19  Agustín Martegani         9   Regates intentados  0.085714
# 33  Agustín Martegani         3  Regates completados  0.507185
# 72  Agustín Martegani         2          Asistencias  1.373626
# 99  Agustín Martegani         9        Recibió falta  0.735534
#                Nombre  Posicion     Atributo     Valor
# 70  Francisco Pizzini         0  Asistencias  1.680358
# 86  Francisco Pizzini         6  Pases clave  0.774119
#               Nombre  Posicion     Atributo     Valor
# 71  Franco Cristaldo         1  Asistencias  1.505017
# 85  Franco Cristaldo         5  Pases clave  0.780009
#          Nombre  Posicion             Atributo     Valor
# 18  Enzo Roldán         8   Regates intentados  0.086631
# 31  Enzo Roldán         1  Regates completados  0.531595
# 65  Enzo Roldán         5                Goles  0.471846
# 91  Enzo Roldán         1        Recibió falta  0.991202
#             Nombre  Posicion             Atributo     Valor
# 38  Edwin Mosquera         8  Regates completados  0.396312
# 75  Edwin Mosquera         5          Asistencias  0.805009
# 96  Edwin Mosquera         6        Recibió falta  0.766324
#              Nombre  Posicion             Atributo     Valor
# 16  Gastón González         6   Regates intentados  0.095000
# 36  Gastón González         6  Regates completados  0.433925
# 80  Gastón González         0          Pases clave  1.162791
#             Nombre  Posicion       Atributo     Valor
# 77  Sergio Quiroga         7    Asistencias  0.736498
# 95  Sergio Quiroga         5  Recibió falta  0.788743
#             Nombre  Posicion     Atributo     Valor
# 62  Carlos Rotondi         2        Goles  0.512996
# 74  Carlos Rotondi         4  Asistencias  1.006261
#            Nombre  Posicion         Atributo     Valor
# 57   Lucas Janson         7   Tiros a puerta  0.531463
# 66   Lucas Janson         6            Goles  0.400160
# 92   Lucas Janson         2    Recibió falta  0.980713
# 125  Lucas Janson         5  Fueras de juego -0.497760
#              Nombre  Posicion          Atributo     Valor
# 50   Brahian Alemán         0    Tiros a puerta  1.043987
# 68   Brahian Alemán         8             Goles  0.393030
# 83   Brahian Alemán         3       Pases clave  0.865711
# 111  Brahian Alemán         1  Posesion perdida -1.008843
#            Nombre  Posicion            Atributo     Valor
# 17  Luca Orellano         7  Regates intentados  0.093750
# 59  Luca Orellano         9      Tiros a puerta  0.488281
# 89  Luca Orellano         9         Pases clave  0.700789
#          Nombre  Posicion                  Atributo     Valor
# 2   Jorge Morel         2  Duelos aéreos efectuados  0.070295
# 44  Jorge Morel         4     Duelos aereos ganados  0.406470
# 78  Jorge Morel         8               Asistencias  0.718162
#                Nombre  Posicion        Atributo     Valor
# 55  Ezequiel Bullaude         5  Tiros a puerta  0.543478
# 63  Ezequiel Bullaude         3           Goles  0.511509
#              Nombre  Posicion     Atributo     Valor
# 76   Enzo Fernández         6  Asistencias  0.799432
# 81   Enzo Fernández         1  Pases clave  1.035808
# 106  Enzo Fernández         6  Tiros fuera -0.817396
#               Nombre  Posicion     Atributo     Valor
# 82  Emiliano Vecchio         2  Pases clave  0.930233
#            Nombre  Posicion            Atributo     Valor
# 11  Malcom Braida         1  Regates intentados  0.102062
# 97  Malcom Braida         7       Recibió falta  0.743117
#            Nombre  Posicion       Atributo     Valor
# 93  Rodrigo Garro         3  Recibió falta  0.801361
#          Nombre  Posicion                  Atributo     Valor
# 1    Ramón Sosa         1  Duelos aéreos efectuados  0.071429
# 42   Ramón Sosa         2     Duelos aereos ganados  0.534500
# 98   Ramón Sosa         8             Recibió falta  0.735534
# 123  Ramón Sosa         3           Fueras de juego -0.580720
#             Nombre  Posicion                  Atributo     Valor
# 0   Joaquín Ibáñez         0  Duelos aéreos efectuados  0.087197
# 40  Joaquín Ibáñez         0     Duelos aereos ganados  0.672269
#                Nombre  Posicion             Atributo     Valor
# 12  Ignacio Fernandez         2   Regates intentados  0.101299
# 30  Ignacio Fernandez         0  Regates completados  0.614770
# ################################################################################
# Aqui se encuentra el informe para jugadores categorizado en forma ofensivo
# ################################################################################
#               Nombre  Posicion                Atributo     Valor
# 18   Sebastián Villa         8      Regates intentados  0.074611
# 28   Sebastián Villa         8  Porc Efectividad pases  0.171278
# 34   Sebastián Villa         4     Regates completados  0.331116
# 51   Sebastián Villa         1          Tiros a puerta  0.971503
# 75   Sebastián Villa         5             Asistencias  0.896772
# 86   Sebastián Villa         6             Pases clave  0.697158
# 94   Sebastián Villa         4           Recibió falta  0.693613
# 120  Sebastián Villa         0         Fueras de juego -1.516492
#            Nombre  Posicion                  Atributo     Valor
# 8   Mateo Retegui         8  Duelos aéreos efectuados  0.104458
# 46  Mateo Retegui         6     Duelos aereos ganados  0.713828
# 78  Mateo Retegui         8               Asistencias  0.776130
# 89  Mateo Retegui         9               Pases clave  0.670411
#                  Nombre  Posicion                  Atributo     Valor
# 2    Juan Manuel García         2  Duelos aéreos efectuados  0.162100
# 40   Juan Manuel García         0     Duelos aereos ganados  1.076913
# 72   Juan Manuel García         2               Asistencias  1.127537
# 97   Juan Manuel García         7             Recibió falta  0.603761
# 119  Juan Manuel García         9          Posesion perdida -0.786113
#              Nombre  Posicion                Atributo     Valor
# 26  Jhonatan Candia         6  Porc Efectividad pases  0.173727
# 35  Jhonatan Candia         5     Regates completados  0.314185
# 59  Jhonatan Candia         9          Tiros a puerta  0.829646
# 64  Jhonatan Candia         4                   Goles  0.780843
#             Nombre  Posicion                Atributo     Valor
# 13  Ezequiel Barco         3      Regates intentados  0.084375
# 20  Ezequiel Barco         0  Porc Efectividad pases  0.184913
# 30  Ezequiel Barco         0     Regates completados  0.499260
# 90  Ezequiel Barco         0           Recibió falta  1.206736
#            Nombre  Posicion                Atributo     Valor
# 22  Lucas Beltrán         2  Porc Efectividad pases  0.178682
# 39  Lucas Beltrán         9     Regates completados  0.224525
# 68  Lucas Beltrán         8                   Goles  0.697512
# 85  Lucas Beltrán         5             Pases clave  0.709099
#               Nombre  Posicion                  Atributo     Valor
# 1    Jonathan Torres         1  Duelos aéreos efectuados  0.166557
# 41   Jonathan Torres         1     Duelos aereos ganados  1.073148
# 58   Jonathan Torres         8            Tiros a puerta  0.842697
# 98   Jonathan Torres         8             Recibió falta  0.601651
# 102  Jonathan Torres         2               Tiros fuera -0.908976
#               Nombre  Posicion        Atributo     Valor
# 52  Miguel Merentiel         2  Tiros a puerta  0.958807
# 63  Miguel Merentiel         3           Goles  0.802139
#              Nombre  Posicion          Atributo     Valor
# 54   Julián Álvarez         4    Tiros a puerta  0.911458
# 66   Julián Álvarez         6             Goles  0.735294
# 83   Julián Álvarez         3       Pases clave  0.830565
# 117  Julián Álvarez         7  Posesion perdida -0.804455
#              Nombre  Posicion     Atributo     Valor
# 70  Pablo Argañaraz         0  Asistencias  1.656238
#           Nombre  Posicion       Atributo     Valor
# 88  Agustín Urzi         8    Pases clave  0.672757
# 92  Agustín Urzi         2  Recibió falta  0.772311
#               Nombre  Posicion             Atributo     Valor
# 11  Federico Andrada         1   Regates intentados  0.091244
# 32  Federico Andrada         2  Regates completados  0.458103
# 91  Federico Andrada         1        Recibió falta  0.854169
#                 Nombre  Posicion               Atributo     Valor
# 49  Cristian Tarragona         9  Duelos aereos ganados  0.526364
# 57  Cristian Tarragona         7         Tiros a puerta  0.848416
#             Nombre  Posicion       Atributo     Valor
# 69  Matías Cóccaro         9          Goles  0.676997
# 95  Matías Cóccaro         5  Recibió falta  0.632071
#            Nombre  Posicion                  Atributo     Valor
# 6    Leandro Díaz         6  Duelos aéreos efectuados  0.109318
# 45   Leandro Díaz         5     Duelos aereos ganados  0.722413
# 50   Leandro Díaz         0            Tiros a puerta  1.106195
# 61   Leandro Díaz         1                     Goles  1.041124
# 112  Leandro Díaz         2          Posesion perdida -0.898099
# 126  Leandro Díaz         6           Fueras de juego -1.079214
#           Nombre  Posicion     Atributo    Valor
# 73  Pablo Mouche         3  Asistencias  0.96691
#                  Nombre  Posicion        Atributo     Valor
# 53  Pablo Daniel Magnin         3  Tiros a puerta  0.952744
#             Nombre  Posicion     Atributo     Valor
# 74  Lisandro López         4  Asistencias  0.925545
#               Nombre  Posicion        Atributo     Valor
# 55   Darío Benedetto         5  Tiros a puerta  0.876168
# 62   Darío Benedetto         2           Goles  0.824629
# 107  Darío Benedetto         7     Tiros fuera -0.787567
#            Nombre  Posicion                Atributo     Valor
# 25  Tadeo Allende         5  Porc Efectividad pases  0.174584
# 87  Tadeo Allende         7             Pases clave  0.695357
# ################################################################################
# Aqui se encuentra el informe para jugadores categorizado en forma global
# ################################################################################
#               Nombre  Posicion             Atributo     Valor
# 72   Lucas Rodríguez         2   Centros intentados  0.125000
# 100  Lucas Rodríguez         0  Centros completados  0.428571
# 160  Lucas Rodríguez         0          Asistencias  1.831502
# 240  Lucas Rodríguez         0          Pases clave  1.582028
#                     Nombre  Posicion                    Atributo     Valor
# 12   Christian Javier Báez         2               Pases totales  0.186317
# 111  Christian Javier Báez         1  Balones largos completados  0.525815
# 144  Christian Javier Báez         4             Pases acertados  0.678116
# 223  Christian Javier Báez         3              Intercepciones  1.349325
# 234  Christian Javier Báez         4                      Toques  0.705631
#                  Nombre  Posicion                  Atributo     Valor
# 34   Juan Manuel García         4         Duelos efectuados  0.138762
# 42   Juan Manuel García         2  Duelos aéreos efectuados  0.162100
# 80   Juan Manuel García         0            Duelos ganados  0.804555
# 120  Juan Manuel García         0     Duelos aereos ganados  1.076913
# 166  Juan Manuel García         6               Asistencias  1.127537
#                Nombre  Posicion               Atributo     Valor
# 17   Nazareno Colombo         7          Pases totales  0.173698
# 128  Nazareno Colombo         8  Duelos aereos ganados  0.673259
# 201  Nazareno Colombo         1               Despejes  1.451487
# 235  Nazareno Colombo         5                 Toques  0.694609
#          Nombre  Posicion                    Atributo     Valor
# 11   Paulo Díaz         1               Pases totales  0.193075
# 113  Paulo Díaz         3  Balones largos completados  0.498542
# 123  Paulo Díaz         3       Duelos aereos ganados  0.821086
# 141  Paulo Díaz         1             Pases acertados  0.712192
# 232  Paulo Díaz         2                      Toques  0.746308
#                Nombre  Posicion           Atributo     Valor
# 213  Nicolás Ferreyra         3  Disparos Bloq Def  1.829268
# 229  Nicolás Ferreyra         9     Intercepciones  1.120690
#              Nombre  Posicion         Atributo     Valor
# 13   Lucas Villalba         3    Pases totales  0.183749
# 147  Lucas Villalba         7  Pases acertados  0.658999
# 227  Lucas Villalba         7   Intercepciones  1.146771
# 231  Lucas Villalba         1           Toques  0.758149
#                Nombre  Posicion           Atributo     Valor
# 204  Ignacio Gariglio         4           Despejes  1.193171
# 219  Ignacio Gariglio         9  Disparos Bloq Def  1.550227
#                 Nombre  Posicion                       Atributo     Valor
# 9    Agustín Martegani         9  Duelos en el suelo efectuados  0.108466
# 99   Agustín Martegani         9     Duelos en el suelo ganados  0.655738
# 136  Agustín Martegani         6            Regates completados  0.507185
# 164  Agustín Martegani         4                    Asistencias  1.373626
#                Nombre  Posicion           Atributo     Valor
# 173  Gianluca Ferrari         3           Entradas  0.817052
# 216  Gianluca Ferrari         6  Disparos Bloq Def  1.707317
#              Nombre  Posicion         Atributo     Valor
# 16   Enzo Fernández         6    Pases totales  0.175642
# 149  Enzo Fernández         9  Pases acertados  0.632250
# 238  Enzo Fernández         8           Toques  0.679779
# 244  Enzo Fernández         4      Pases clave  1.035808
#              Nombre  Posicion        Atributo     Valor
# 156  Julián Álvarez         6           Goles  0.735294
# 186  Julián Álvarez         6  Tiros a puerta  0.911458
# 249  Julián Álvarez         9     Pases clave  0.830565
#          Nombre  Posicion                       Atributo     Valor
# 5    Ivan Gómez         5  Duelos en el suelo efectuados  0.115016
# 85   Ivan Gómez         5                 Duelos ganados  0.690490
# 90   Ivan Gómez         0     Duelos en el suelo ganados  0.829623
# 172  Ivan Gómez         2                       Entradas  0.817165
#             Nombre  Posicion                  Atributo     Valor
# 31   Lucas Barrios         1         Duelos efectuados  0.145455
# 40   Lucas Barrios         0  Duelos aéreos efectuados  0.174179
# 86   Lucas Barrios         6            Duelos ganados  0.668285
# 124  Lucas Barrios         4     Duelos aereos ganados  0.742115
# 190  Lucas Barrios         0         Disparos bloq ATA  0.649351
#          Nombre  Posicion                  Atributo     Valor
# 36   José López         6         Duelos efectuados  0.136296
# 46   José López         6  Duelos aéreos efectuados  0.115033
# 83   José López         3            Duelos ganados  0.716600
# 125  José López         5     Duelos aereos ganados  0.725624
# 196  José López         6         Disparos bloq ATA  0.444444
#               Nombre  Posicion                  Atributo     Valor
# 32   Jonathan Torres         2         Duelos efectuados  0.142921
# 41   Jonathan Torres         1  Duelos aéreos efectuados  0.166557
# 81   Jonathan Torres         1            Duelos ganados  0.749321
# 121  Jonathan Torres         1     Duelos aereos ganados  1.073148
# 189  Jonathan Torres         9            Tiros a puerta  0.842697
# 276  Jonathan Torres         6               Tiros fuera -0.908976
#                  Nombre  Posicion           Atributo    Valor
# 210  Haibrany Ruiz Diaz         0  Disparos Bloq Def  1.95122
#                Nombre  Posicion           Atributo    Valor
# 211  Leonardo Morales         1  Disparos Bloq Def  1.95122
#            Nombre  Posicion           Atributo     Valor
# 212  Lucas Suarez         2  Disparos Bloq Def  1.948333
#              Nombre  Posicion         Atributo     Valor
# 10   Davíd Martínez         0    Pases totales  0.230517
# 140  Davíd Martínez         0  Pases acertados  0.890546
# 230  Davíd Martínez         0           Toques  0.818449
