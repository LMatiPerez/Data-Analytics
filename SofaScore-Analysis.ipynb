# %%
import pandas as pd

BIGDATA=pd.read_excel('Pepechum.xlsx',sheet_name='BIGDATA',index_col='Nombre')
GLOBAL=pd.read_excel('Pupeta.xlsx',sheet_name='GLOBAL',index_col='Unnamed: 0').T
Tiempo1=pd.read_excel('Pupeta.xlsx',sheet_name='1TIEMPO',index_col='Unnamed: 0').T
Tiempo2=pd.read_excel('Pupeta.xlsx',sheet_name='2TIEMPO',index_col='Unnamed: 0').T
GLOBAL = GLOBAL[GLOBAL['Regates'].notna()]
Vacios = GLOBAL[ GLOBAL['Posesión de balón'] == ' ' ].index
GLOBAL.drop(Vacios , inplace=True)
Tiempo1 = Tiempo1[Tiempo1['Regates'].notna()]
Vacios = Tiempo1[ Tiempo1['Posesión de balón'] == ' ' ].index
Tiempo1.drop(Vacios , inplace=True)
Tiempo2 = Tiempo2[Tiempo2['Regates'].notna()]
Vacios = Tiempo2[ Tiempo2['Posesión de balón'] == ' ' ].index
Tiempo2.drop(Vacios , inplace=True)
#### Agregado de Rival-Resultado-Condicion a BIGDATA
Fixture=pd.read_excel('Pumpet.xlsx')
ContadorFixture=0
inicio=0
BIGDATA['Resultado']=""
BIGDATA['Rival']=''
BIGDATA['Condicion']=''
BIGDATA['Local']=''
BIGDATA['Visitante']=''
BIGDATA['Partido']=''
for i in range(0,len(BIGDATA.index)):
    if BIGDATA['Equipo'].iloc[i]==Fixture['Local'][ContadorFixture]:
        BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
        BIGDATA['Condicion'][i]='Home'
        BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
        BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
        BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]
    elif BIGDATA['Equipo'].iloc[i]==Fixture['Visitante'][ContadorFixture]:
        BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
        BIGDATA['Condicion'][i]='Away'
        BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
        BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
        BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
    else:
        for a in range(inicio,i):
            BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]      
        inicio=i
        ContadorFixture=ContadorFixture+1
        if BIGDATA['Equipo'].iloc[i]==Fixture['Local'][ContadorFixture]:
            BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
            BIGDATA['Condicion'][i]='Home'
            BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
            BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
            BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]   
        else:
            BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
            BIGDATA['Condicion'][i]='Away'
            BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
            BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
            BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
for a in range(inicio,i+1):
    BIGDATA['Resultado'][a]=BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]   
####
BIGDATA.insert(loc = 4, column = 'Goles y Asistencias', value = BIGDATA['Goles']+BIGDATA['Asistencias'])
### Numerizando GLOBAL
GLOBAL['Posesión de balón']=GLOBAL['Posesión de balón'].astype('float64')*100
GLOBAL[['Tiros totales', 'Tiros a puerta', 'Tiros fuera','Disparos bloqueados', 'Saques de esquina', 'Fueras de juego',
        'Faltas','Tarjetas amarillas', 'Tarjetas rojas', 'Ocasiones claras','Ocasiones claras falladas', 'Disparos al Palo',
        'Contraataques','Tiros en contraataque', 'Goles en contraataque','Tiros dentro del área',
        'Tiros desde fuera del área', 'Paradas','Pases', 'Pases totales', 'Porc. Pases efectivos','Pases largos efectivos',
        'Pases largos totales','Porc. Pases largos efectivos', 'Centros completados','Centros intentados',
        'Porc. Centros completados','Regates completados', 'Regates intentados', 'Porc. Regates efectivos','Posesión perdida',
        'Duelos ganados', 'Balones aéreos ganados','Entradas', 'Intercepciones', 'Despejes']]=GLOBAL[['Tiros totales', 'Tiros a puerta', 'Tiros fuera',
       'Disparos bloqueados', 'Saques de esquina', 'Fueras de juego', 'Faltas','Tarjetas amarillas', 'Tarjetas rojas','Ocasiones claras',
       'Ocasiones claras falladas', 'Disparos al Palo', 'Contraataques','Tiros en contraataque', 'Goles en contraataque',
       'Tiros dentro del área', 'Tiros desde fuera del área', 'Paradas','Pases', 'Pases totales', 'Porc. Pases efectivos',
       'Pases largos efectivos', 'Pases largos totales','Porc. Pases largos efectivos', 'Centros completados',
       'Centros intentados', 'Porc. Centros completados','Regates completados', 'Regates intentados', 'Porc. Regates efectivos',
       'Posesión perdida', 'Duelos ganados', 'Balones aéreos ganados','Entradas', 'Intercepciones', 'Despejes']].astype('int64')
####
pd.options.display.max_columns = None
# Out:
# <ipython-input-1-9e4bb8c8d9df>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Condicion'][i]='Home'
# <ipython-input-1-9e4bb8c8d9df>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]
# <ipython-input-1-9e4bb8c8d9df>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Condicion'][i]='Away'
# <ipython-input-1-9e4bb8c8d9df>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
# <ipython-input-1-9e4bb8c8d9df>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Rival'][i]=Fixture['Visitante'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Condicion'][i]='Home'
# <ipython-input-1-9e4bb8c8d9df>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Partido'][i]=BIGDATA['Equipo'][i]+'-'+BIGDATA['Rival'][i]
# <ipython-input-1-9e4bb8c8d9df>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Rival'][i]=Fixture['Local'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Condicion'][i]='Away'
# <ipython-input-1-9e4bb8c8d9df>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Local'][i]=Fixture['L'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Visitante'][i]=Fixture['V'][ContadorFixture]
# <ipython-input-1-9e4bb8c8d9df>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Partido'][i]=BIGDATA['Rival'][i]+'-'+BIGDATA['Equipo'][i]
# <ipython-input-1-9e4bb8c8d9df>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BIGDATA['Resultado'][a]=BIGDATA['Resultado'][a]=Fixture['Resultado'][ContadorFixture]

# %%
BIGDATA['Porc Efectividad pases']=BIGDATA['Porc Efectividad pases']*(BIGDATA['Minutos jugados']/90)
listas=['Goles','Asistencias','Entradas','Goles y Asistencias','Pases acertados','Pases totales','Porc Efectividad pases',
        'Duelos ganados','Duelos en el suelo ganados','Duelos aereos ganados','Tiros a puerta','Tiros fuera',
        'Regates completados','Despejes','Disparos Bloq Def','Intercepciones','Regateado','Pases clave','Posesion perdida',
        'Faltas','Recibió falta','Fueras de juego']
lis=[1.02,0.52,5.63,1.36,68.38,76.92,0.9,11.66,9.15,5.88,1.92,1.78,5.07,5.54,0.82,2.9,2.93,3.01,24.24,3.46,4.37,1.23]

c=BIGDATA.max()
for k,o in zip(listas,lis):
    c[k]=o

# %%
variables=['Goles','Asistencias','Entradas','Goles y Asistencias','Pases acertados','Pases totales','Porc Efectividad pases',
       'Duelos efectuados','Duelos ganados','Duelos en el suelo efectuados','Duelos en el suelo ganados',
       'Duelos aéreos efectuados','Duelos aereos ganados','Tiros a puerta','Tiros fuera','Disparos bloq ATA',
       'Regates intentados','Regates completados','Despejes','Disparos Bloq Def','Intercepciones','Entradas.1',
       'Regateado','Toques','Pases clave','Centros intentados','Centros completados','Balones largos intentados',
       'Balones largos completados','Posesion perdida','Faltas','Recibió falta','Fueras de juego']
defensor=['Pases totales','Porc Efectividad pases','Duelos efectuados','Duelos en el suelo efectuados',
          'Duelos aéreos efectuados','Balones largos intentados','Pases acertados','Duelos ganados',
          'Duelos en el suelo ganados','Balones largos completados','Duelos aereos ganados','Entradas','Despejes',
          'Disparos Bloq Def','Intercepciones','Toques','Regateado','Faltas']
medio=['Duelos en el suelo efectuados','Pases totales','Porc Efectividad pases','Duelos efectuados',
       'Duelos aéreos efectuados','Regates intentados','Balones largos intentados','Centros intentados','Duelos ganados',
       'Duelos en el suelo ganados','Centros completados','Balones largos completados','Duelos aereos ganados',
       'Regates completados','Pases acertados','Goles','Asistencias','Entradas','Tiros a puerta','Disparos bloq ATA',
       'Despejes','Disparos Bloq Def','Intercepciones','Toques','Pases clave','Recibió falta','Regateado','Tiros fuera',
       'Posesion perdida','Faltas','Fueras de juego']
delantero=['Duelos aéreos efectuados','Regates intentados','Porc Efectividad pases','Regates completados',
           'Duelos aereos ganados','Tiros a puerta','Goles','Asistencias','Pases clave','Recibió falta','Tiros fuera',
           'Posesion perdida','Fueras de juego']
eleccion=input('Opciones - defensor, medio, medio defensivo, medio ofensivo, delantero - : ')
if eleccion=='defensor':
    lista=defensor
    BIGDATA=BIGDATA.loc[BIGDATA['Posicion']=="D"]
elif eleccion=='medio':
    lista=medio
    BIGDATA=BIGDATA.loc[BIGDATA['Posicion']=="M"]
elif eleccion=='medio ofensivo':
    lista=delantero
    BIGDATA=BIGDATA.loc[BIGDATA['Posicion']=="M"]
elif eleccion=='medio defensivo':
    lista=defensor
    BIGDATA=BIGDATA.loc[BIGDATA['Posicion']=="M"]
else:
    lista=delantero
    BIGDATA=BIGDATA.loc[BIGDATA['Posicion']=="F"]
BIG=BIGDATA.groupby('Nombre').sum()
for a in variables:
    BIG[a]=(BIG[a]/c[a])/(BIG['Minutos jugados']/90)
BIG.sort_values(by='Nombre')
# Out:
# Opciones: defensor, medio, medio defensivo, medio ofensivo, delanteromedio ofensivo
#                   Goles  Asistencias  Entradas  Goles y Asistencias  \
# Nombre
# Aaron Molinas       0.0     1.680358  0.620807             0.642490
# Abel Bustos         0.0     0.000000  3.552398             0.000000
# Agustín Almendra    0.0     0.000000  0.000000             0.000000
# Agustín Baldi       0.0     0.000000  1.918295             0.000000
# Agustín Bouzat      0.0     0.000000  0.570921             0.000000
# ...                 ...          ...       ...                  ...
# Yair Arismendi      0.0     0.000000  0.260638             0.000000
# Yeison Gordillo     0.0     0.000000  1.012675             0.000000
# Ángel González      0.0     0.000000  0.000000             0.000000
# Ángelo Martino      0.0     0.000000  0.000000             0.000000
# ‪Ignacio Schor      0.0     1.291619  0.238594             0.493854
#
#                   Pases acertados  Pases totales  Porc Efectividad pases  \
# Nombre
# Aaron Molinas            0.600584       0.658861                0.921143
# Abel Bustos              0.146242       0.130005                1.111111
# Agustín Almendra         0.789705       0.780031                1.085926
# Agustín Baldi            0.315882       0.421217                0.744444
# Agustín Bouzat           0.334919       0.396980                0.846032
# ...                           ...            ...                     ...
# Yair Arismendi           0.135909       0.209845                0.646739
# Yeison Gordillo          0.321599       0.450018                0.702916
# Ángel González           0.415634       0.422273                0.959733
# Ángelo Martino           0.000000       1.170047                0.000000
# ‪Ignacio Schor           0.230822       0.279414                0.816045
#
#                   Duelos efectuados  Duelos ganados  \
# Nombre
# Aaron Molinas              0.611650        0.899266
# Abel Bustos                0.666667        1.715266
# Agustín Almendra           0.200000        0.000000
# Agustín Baldi              0.720000        1.234991
# Agustín Bouzat             0.415179        0.551335
# ...                             ...             ...
# Yair Arismendi             0.358696        0.545343
# Yeison Gordillo            0.556561        0.698525
# Ángel González             0.338346        0.290177
# Ángelo Martino             6.000000        0.000000
# ‪Ignacio Schor             0.492537        0.633624
#
#                   Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Aaron Molinas                          0.517799                    0.763966
# Abel Bustos                            0.740741                    2.185792
# Agustín Almendra                       0.222222                    0.000000
# Agustín Baldi                          0.533333                    1.180328
# Agustín Bouzat                         0.386905                    0.570843
# ...                                         ...                         ...
# Yair Arismendi                         0.271739                    0.427655
# Yeison Gordillo                        0.437406                    0.712113
# Ángel González                         0.300752                    0.369777
# Ángelo Martino                         6.666667                    0.000000
# ‪Ignacio Schor                         0.435323                    0.734035
#
#                   Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Aaron Molinas                     0.256996               0.594413
# Abel Bustos                       0.000000               0.000000
# Agustín Almendra                  0.000000               0.000000
# Agustín Baldi                     0.423529               0.612245
# Agustín Bouzat                    0.118172               0.204993
# ...                                    ...                    ...
# Yair Arismendi                    0.201407               0.415927
# Yeison Gordillo                   0.287463               0.277034
# Ángel González                    0.119416               0.000000
# Ángelo Martino                    0.000000               0.000000
# ‪Ignacio Schor                    0.177788               0.114225
#
#                   Minutos jugados  Tiros a puerta  Tiros fuera  \
# Nombre
# Aaron Molinas                 103        0.000000     0.000000
# Abel Bustos                     9        0.000000     0.000000
# Agustín Almendra               15        0.000000     0.000000
# Agustín Baldi                  25        0.000000     0.000000
# Agustín Bouzat                224        0.209263     0.000000
# ...                           ...             ...          ...
# Yair Arismendi                184        0.000000     0.549585
# Yeison Gordillo               221        0.000000     0.686359
# Ángel González                133        0.000000     0.380164
# Ángelo Martino                  1        0.000000     0.000000
# ‪Ignacio Schor                268        0.174907     0.000000
#
#                   Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Aaron Molinas              0.000000            0.174757             0.344689
# Abel Bustos                0.000000            0.000000             0.000000
# Agustín Almendra           0.000000            0.000000             0.000000
# Agustín Baldi              0.000000            0.000000             0.000000
# Agustín Bouzat             0.133929            0.120536             0.000000
# ...                             ...                 ...                  ...
# Yair Arismendi             0.163043            0.195652             0.000000
# Yeison Gordillo            0.000000            0.000000             0.000000
# Ángel González             0.225564            0.541353             0.533879
# Ángelo Martino             0.000000            0.000000             0.000000
# ‪Ignacio Schor             0.223881            0.302239             0.463658
#
#                   Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Aaron Molinas     0.000000           0.000000        0.602611    0.349515
# Abel Bustos       0.000000           0.000000        0.000000    2.000000
# Agustín Almendra  1.083032           0.000000        0.000000    0.000000
# Agustín Baldi     0.000000           0.000000        0.000000    1.080000
# Agustín Bouzat    0.000000           0.489983        0.277094    0.321429
# ...                    ...                ...             ...         ...
# Yair Arismendi    0.088291           0.596501        0.168666    0.146739
# Yeison Gordillo   0.441054           1.489902        0.421283    0.570136
# Ángel González    0.122147           0.000000        0.000000    0.000000
# Ángelo Martino    0.000000           0.000000       31.034483    0.000000
# ‪Ignacio Schor    0.060617           0.409538        0.231601    0.134328
#
#                   Regateado    Toques  Pases clave  Centros intentados  \
# Nombre
# Aaron Molinas      0.298221  0.615948     1.161178            0.109223
# Abel Bustos        0.000000  0.409836     0.000000            0.000000
# Agustín Almendra   0.000000  0.540984     1.993355            0.000000
# Agustín Baldi      0.000000  0.383607     0.000000            0.000000
# Agustín Bouzat     0.274256  0.461066     0.266967            0.226004
# ...                     ...       ...          ...                 ...
# Yair Arismendi     0.000000  0.344797     0.975011            0.397418
# Yeison Gordillo    0.138990  0.427268     0.000000            0.025452
# Ángel González     0.000000  0.421546     0.000000            0.253759
# Ángelo Martino     0.000000  2.950820     0.000000            0.000000
# ‪Ignacio Schor     0.343844  0.355089     0.557842            0.146922
#
#                   Centros completados  Balones largos intentados  \
# Nombre
# Aaron Molinas                0.109223                   0.291262
# Abel Bustos                  0.000000                   0.000000
# Agustín Almendra             0.000000                   0.166667
# Agustín Baldi                0.000000                   0.100000
# Agustín Bouzat               0.050223                   0.055804
# ...                               ...                        ...
# Yair Arismendi               0.244565                   0.067935
# Yeison Gordillo              0.000000                   0.169683
# Ángel González               0.000000                   0.000000
# Ángelo Martino               0.000000                   0.000000
# ‪Ignacio Schor               0.083955                   0.055970
#
#                   Balones largos completados  Posesion perdida    Faltas  \
# Nombre
# Aaron Molinas                       0.382282          0.793040  0.505079
# Abel Bustos                         0.000000          0.412541  0.000000
# Agustín Almendra                    0.375000          0.247525  1.734104
# Agustín Baldi                       0.000000          0.594059  1.040462
# Agustín Bouzat                      0.075335          0.696163  0.580615
# ...                                      ...               ...       ...
# Yair Arismendi                      0.000000          0.847503  0.141367
# Yeison Gordillo                     0.101810          0.588011  1.412392
# Ángel González                      0.000000          0.614159  0.391151
# Ángelo Martino                      0.000000         11.138614  0.000000
# ‪Ignacio Schor                      0.104944          0.623430  0.582348
#
#                   Recibió falta  Fueras de juego  Fecha
# Nombre
# Aaron Molinas          0.399902         0.000000      8
# Abel Bustos            0.000000         0.000000      1
# Agustín Almendra       0.000000         0.000000      4
# Agustín Baldi          0.000000         0.000000      1
# Agustín Bouzat         0.459709         0.000000     10
# ...                         ...              ...    ...
# Yair Arismendi         0.559646         0.000000     10
# Yeison Gordillo        0.186380         0.331089      7
# Ángel González         0.154849         0.550156     10
# Ángelo Martino         0.000000         0.000000      1
# ‪Ignacio Schor         0.691622         0.546050     10
#
# [269 rows x 35 columns]

# %%
#lista=['Goles y Asistencias','Pases totales','Porc Efectividad pases','Duelos efectuados','Duelos en el suelo efectuados',
       #'Duelos aéreos efectuados','Regates intentados','Balones largos intentados','Centros intentados','Goles',
       #'Asistencias','Pases acertados','Duelos ganados','Duelos en el suelo ganados','Centros completados',
       #'Balones largos completados','Duelos aereos ganados','Regates completados','Entradas',
       #'Tiros a puerta','Disparos bloq ATA','Despejes','Disparos Bloq Def','Intercepciones','Toques',
       #'Pases clave','Recibió falta','Regateado','Tiros fuera',
       #'Posesion perdida','Faltas','Fueras de juego']
ORDEN=BIG.loc[BIG['Minutos jugados']>BIG['Minutos jugados'].max()*0.4]
nombre=[]
posicion=[]
atributo=[]
valor=[]

#'Goles y Asistencias''Regates intentados''Duelos ganados'

for m in lista:
    ORDEN=ORDEN.sort_values(by=m,ascending=False)
    for p in range(1,11):
        nombre.append(ORDEN.index[p-1])
        posicion.append(p-1)
        atributo.append(m)
        valor.append(ORDEN[m][p-1])
        print(ORDEN.index[p])
        print(p)       
MP=pd.DataFrame(columns=['Nombre','Posicion','Atributo','Valor'])
MP['Nombre']=nombre
MP['Posicion']=posicion
MP['Atributo']=atributo
MP['Valor']=valor
# Out:
# Joaquín Ibáñez
# 1
# Fernando Juarez
# 2
# Ramiro Carrera
# 3
# Manuel Castro
# 4
# Enzo Pérez
# 5
# Giuliano Galoppo
# 6
# Ramón Sosa
# 7
# Daniel Juárez
# 8
# Yeison Gordillo
# 9
# Nicolás Bertolo
# 10
# Facundo Farías
# 1
# Luca Orellano
# 2
# Silvio Martínez
# 3
# Carlos Rotondi
# 4
# Carlos Alcaraz
# 5
# Gastón González
# 6
# Nicolás Fernández Mercau
# 7
# Ignacio Fernandez
# 8
# Rodrigo Villagra
# 9
# Enzo Roldán
# 10
# Raúl Loaiza
# 1
# Facundo Farías
# 2
# Juan Ramírez
# 3
# Fausto Vera
# 4
# Pol Fernández
# 5
# Alan Soñora
# 6
# Agustín Mulet
# 7
# Walter Montoya
# 8
# Pedro Emanuel Ojeda
# 9
# Alejandro Galarza
# 10
# Rodrigo Villagra
# 1
# Fernando Valenzuela
# 2
# Matías Rojas
# 3
# Nelson Acevedo
# 4
# Enzo Roldán
# 5
# Nicolás Castro
# 6
# Carlos Rotondi
# 7
# Nicolás Fernández Mercau
# 8
# Carlos Alcaraz
# 9
# Gastón González
# 10
# Joaquín Ibáñez
# 1
# Jorge Morel
# 2
# Ramón Sosa
# 3
# Giuliano Galoppo
# 4
# Ramiro Carrera
# 5
# Daniel Juárez
# 6
# Sebastian Prediger
# 7
# Manuel Castro
# 8
# Julián Chicco
# 9
# Yair Arismendi
# 10
# Silvio Martínez
# 1
# Francisco González
# 2
# Juan Quintero
# 3
# Diego González
# 4
# Giuliano Galoppo
# 5
# Carlos Alcaraz
# 6
# Agustín Martegani
# 7
# Walter Bou
# 8
# Nicolás De la Cruz
# 9
# Lucas Janson
# 10
# Giuliano Galoppo
# 1
# Ivan Gómez
# 2
# Carlos Rotondi
# 3
# Matías Pellegrini
# 4
# Carlos Alcaraz
# 5
# Agustín Martegani
# 6
# Nicolás De la Cruz
# 7
# Enzo Roldán
# 8
# Alan Soñora
# 9
# Silvio Martínez
# 10
# Francisco Pizzini
# 1
# Franco Cristaldo
# 2
# ‪Ignacio Schor
# 3
# Jorge Morel
# 4
# Enzo Fernández
# 5
# Edwin Mosquera
# 6
# Manuel Castro
# 7
# Daniel Juárez
# 8
# Carlos Rotondi
# 9
# Walter Bou
# 10
# Brahian Alemán
# 1
# Yair Arismendi
# 2
# Enzo Fernández
# 3
# Francisco Pizzini
# 4
# Cristian Zabala
# 5
# Matías Rojas
# 6
# Manuel Castro
# 7
# Luca Orellano
# 8
# Ignacio Malcorra
# 9
# Francisco González
# 10
# Johan Carbonero
# 1
# Enzo Roldán
# 2
# Nicolás Bertolo
# 3
# Lucas Janson
# 4
# Sergio Quiroga
# 5
# Gino Infantino
# 6
# Facundo Farías
# 7
# Brahian Alemán
# 8
# Fernando Valenzuela
# 9
# Rodrigo Garro
# 10
# Silvio Martínez
# 1
# Jesús Miguel Soraire
# 2
# Matías Pellegrini
# 3
# Gino Infantino
# 4
# Matías Rojas
# 5
# Nicolás Castro
# 6
# Walter Montoya
# 7
# Francisco Metilli
# 8
# Carlos Rotondi
# 9
# Ezequiel Bullaude
# 10
# Brahian Alemán
# 1
# Nicolás E. Castro
# 2
# Nelson Acevedo
# 3
# Juan Quintero
# 4
# Ramón Sosa
# 5
# Damián Batallini
# 6
# Yair Arismendi
# 7
# Ignacio Malcorra
# 8
# Fernando Valenzuela
# 9
# Ramiro Carrera
# 10
# Nicolás De la Cruz
# 1
# Ramón Sosa
# 2
# Juan Garro
# 3
# Lucas Janson
# 4
# ‪Ignacio Schor
# 5
# Johan Carbonero
# 6
# Juan Quintero
# 7
# Matías Pellegrini
# 8
# Ricardo Centurión
# 9
# Facundo Farías
# 10

# %%
#'Regateado','Tiros fuera','Posesion perdida','Faltas','Fueras de juego'
#for i in range(0,180):
#    MP['Valor'][i]=MP['Valor'][i]*0.2
#for i in range(180,360):
#    MP['Valor'][i]=MP['Valor'][i]*0.8
#for i in range(540,len(MP.index)):
#    MP['Valor'][i]=MP['Valor'][i]*-1

#for i in range(0,450):
#    MP['Valor'][i]=MP['Valor'][i]*0.2
#for i in range(450,900):
#    MP['Valor'][i]=MP['Valor'][i]*0.8
#for i in range(1350,len(MP.index)):
#    MP['Valor'][i]=MP['Valor'][i]*-1
if eleccion=='defensor':
    for i in range(0,60):
        MP['Valor'][i]=MP['Valor'][i]*0.2
    for i in range(60,110):
        MP['Valor'][i]=MP['Valor'][i]*0.8
    for i in range(160,len(MP.index)):
        MP['Valor'][i]=MP['Valor'][i]*-1
elif eleccion=='medio':
    for i in range(0,80):
        MP['Valor'][i]=MP['Valor'][i]*0.2
    for i in range(80,150):
        MP['Valor'][i]=MP['Valor'][i]*0.8
    for i in range(250,len(MP.index)):
        MP['Valor'][i]=MP['Valor'][i]*-1
else:
    for i in range(0,30):
        MP['Valor'][i]=MP['Valor'][i]*0.2
    for i in range(30,50):
        MP['Valor'][i]=MP['Valor'][i]*0.8
    for i in range(100,len(MP.index)):
        MP['Valor'][i]=MP['Valor'][i]*-1
#for i in range(0,90):
#    MP['Valor'][i]=MP['Valor'][i]*0.2
#for i in range(90,180):
#    MP['Valor'][i]=MP['Valor'][i]*0.8
#for i in range(270,len(MP.index)):
#    MP['Valor'][i]=MP['Valor'][i]*-1
MP
# Out:
# <ipython-input-6-54d28b29b181>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MP['Valor'][i]=MP['Valor'][i]*0.2
# <ipython-input-6-54d28b29b181>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MP['Valor'][i]=MP['Valor'][i]*0.8
# <ipython-input-6-54d28b29b181>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MP['Valor'][i]=MP['Valor'][i]*-1
#                 Nombre  Posicion                  Atributo     Valor
# 0          Jorge Morel         0  Duelos aéreos efectuados  0.098169
# 1       Joaquín Ibáñez         1  Duelos aéreos efectuados  0.087197
# 2      Fernando Juarez         2  Duelos aéreos efectuados  0.082353
# 3       Ramiro Carrera         3  Duelos aéreos efectuados  0.074510
# 4        Manuel Castro         4  Duelos aéreos efectuados  0.073171
# ..                 ...       ...                       ...       ...
# 125     ‪Ignacio Schor         5           Fueras de juego -0.546050
# 126    Johan Carbonero         6           Fueras de juego -0.544020
# 127      Juan Quintero         7           Fueras de juego -0.504626
# 128  Matías Pellegrini         8           Fueras de juego -0.491079
# 129  Ricardo Centurión         9           Fueras de juego -0.421733
#
# [130 rows x 4 columns]

# %%
# ACA ESTA EL LISTADO
Mejores=list(MP.groupby('Nombre').sum().sort_values(by='Valor',ascending=False).head(20).index)

for a in Mejores:
    print(MP.loc[MP['Nombre']==a])
# Out:
#                Nombre  Posicion        Atributo     Valor
# 57  Agustín Martegani         7  Tiros a puerta  0.548246
# 66  Agustín Martegani         6           Goles  0.515996
# 70  Agustín Martegani         0     Asistencias  2.024291
#                Nombre  Posicion     Atributo     Valor
# 71  Francisco Pizzini         1  Asistencias  1.466754
# 84  Francisco Pizzini         4  Pases clave  0.886874
#          Nombre  Posicion             Atributo     Valor
# 35  Enzo Roldán         5  Regates completados  0.531595
# 68  Enzo Roldán         8                Goles  0.471846
# 92  Enzo Roldán         2        Recibió falta  0.991202
#             Nombre  Posicion     Atributo     Valor
# 75  Enzo Fernández         5  Asistencias  1.009195
# 83  Enzo Fernández         3  Pases clave  0.958903
#              Nombre  Posicion          Atributo     Valor
# 50   Brahian Alemán         0    Tiros a puerta  1.044568
# 81   Brahian Alemán         1       Pases clave  1.082742
# 98   Brahian Alemán         8     Recibió falta  0.803146
# 111  Brahian Alemán         1  Posesion perdida -1.013541
#          Nombre  Posicion                  Atributo     Valor
# 0   Jorge Morel         0  Duelos aéreos efectuados  0.098169
# 42  Jorge Morel         2     Duelos aereos ganados  0.648736
# 74  Jorge Morel         4               Asistencias  1.146205
#            Nombre  Posicion                  Atributo     Valor
# 4   Manuel Castro         4  Duelos aéreos efectuados  0.073171
# 48  Manuel Castro         8     Duelos aereos ganados  0.348432
# 77  Manuel Castro         7               Asistencias  0.703565
# 87  Manuel Castro         7               Pases clave  0.729276
#             Nombre  Posicion             Atributo     Valor
# 15  Carlos Alcaraz         5   Regates intentados  0.097590
# 39  Carlos Alcaraz         9  Regates completados  0.427746
# 56  Carlos Alcaraz         6       Tiros a puerta  0.564759
# 65  Carlos Alcaraz         5                Goles  0.531538
#               Nombre  Posicion     Atributo     Valor
# 72  Franco Cristaldo         2  Asistencias  1.321198
#              Nombre  Posicion            Atributo     Valor
# 16  Gastón González         6  Regates intentados  0.093333
# 80  Gastón González         0         Pases clave  1.218162
#                Nombre  Posicion       Atributo     Valor
# 90  Gustavo del Prete         0  Recibió falta  1.227515
#            Nombre  Posicion                  Atributo     Valor
# 8   Daniel Juárez         8  Duelos aéreos efectuados  0.059058
# 46  Daniel Juárez         6     Duelos aereos ganados  0.390276
# 78  Daniel Juárez         8               Asistencias  0.689549
#             Nombre  Posicion                Atributo     Valor
# 11  Facundo Farías         1      Regates intentados  0.111236
# 22  Facundo Farías         2  Porc Efectividad pases  0.201111
# 97  Facundo Farías         7           Recibió falta  0.809914
#              Nombre  Posicion             Atributo     Valor
# 14   Carlos Rotondi         4   Regates intentados  0.098824
# 37   Carlos Rotondi         7  Regates completados  0.445527
# 63   Carlos Rotondi         3                Goles  0.692042
# 79   Carlos Rotondi         9          Asistencias  0.678733
# 109  Carlos Rotondi         9          Tiros fuera -0.793126
#              Nombre  Posicion       Atributo     Valor
# 93  Nicolás Bertolo         3  Recibió falta  0.961098
#             Nombre  Posicion       Atributo     Valor
# 95  Sergio Quiroga         5  Recibió falta  0.833322
#              Nombre  Posicion                  Atributo     Valor
# 2   Fernando Juarez         2  Duelos aéreos efectuados  0.082353
# 40  Fernando Juarez         0     Duelos aereos ganados  0.748299
#            Nombre  Posicion            Atributo     Valor
# 12  Luca Orellano         2  Regates intentados  0.110204
# 88  Luca Orellano         8         Pases clave  0.711913
#             Nombre  Posicion     Atributo     Valor
# 76  Edwin Mosquera         6  Asistencias  0.805009
#              Nombre  Posicion     Atributo     Valor
# 85  Cristian Zabala         5  Pases clave  0.762764

# %%
Mejores
for a in Mejores:
    print(BIGDATA.loc[BIGDATA.index==a])
#BIGDATA
# Out:
#                         Equipo  Goles  Asistencias  Entradas  \
# Nombre
# Agustín Martegani  San Lorenzo      0            0         1
# Agustín Martegani  San Lorenzo      0            0         0
# Agustín Martegani  San Lorenzo      1            1         2
# Agustín Martegani  San Lorenzo      0            1         0
#
#                    Goles y Asistencias  Pases acertados  Pases totales  \
# Nombre
# Agustín Martegani                    0                0              2
# Agustín Martegani                    0                4              7
# Agustín Martegani                    2               12             14
# Agustín Martegani                    1                9             15
#
#                    Porc Efectividad pases  Duelos efectuados  Duelos ganados  \
# Nombre
# Agustín Martegani                0.000000                  3               1
# Agustín Martegani                0.171000                  5               2
# Agustín Martegani                0.430000                 12               7
# Agustín Martegani                0.546667                 10               3
#
#                    Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Agustín Martegani                              2                           1
# Agustín Martegani                              4                           2
# Agustín Martegani                             12                           7
# Agustín Martegani                              9                           3
#
#                    Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Agustín Martegani                         1                      0
# Agustín Martegani                         1                      0
# Agustín Martegani                         0                      0
# Agustín Martegani                         1                      0
#
#                    Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Agustín Martegani               17        M               0            0
# Agustín Martegani               27        M               0            0
# Agustín Martegani               45        M               1            1
# Agustín Martegani               82        M               1            0
#
#                    Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Agustín Martegani                  0                   0                    0
# Agustín Martegani                  0                   1                    1
# Agustín Martegani                  0                   4                    3
# Agustín Martegani                  0                   2                    0
#
#                    Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Agustín Martegani         0                  0               0           1
# Agustín Martegani         0                  0               1           0
# Agustín Martegani         0                  0               0           2
# Agustín Martegani         1                  0               0           0
#
#                    Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Agustín Martegani          0       7            0                   0
# Agustín Martegani          0      12            0                   0
# Agustín Martegani          2      32            2                   2
# Agustín Martegani          0      30            1                   1
#
#                    Centros completados  Balones largos intentados  \
# Nombre
# Agustín Martegani                    0                          0
# Agustín Martegani                    0                          1
# Agustín Martegani                    1                          1
# Agustín Martegani                    1                          2
#
#                    Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Agustín Martegani                           0                 5       1
# Agustín Martegani                           0                 4       1
# Agustín Martegani                           1                 8       0
# Agustín Martegani                           1                13       3
#
#                    Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Agustín Martegani              0                0
# Agustín Martegani              1                0
# Agustín Martegani              2                0
# Agustín Martegani              3                0
#
#                   Salidas intentadas Salidas completadas Despejes por alto  \
# Nombre
# Agustín Martegani
# Agustín Martegani
# Agustín Martegani
# Agustín Martegani
#
#                                               Notas  Fecha Resultado  \
# Nombre
# Agustín Martegani                             -,-,-      1       0-0
# Agustín Martegani                             -,-,-      2       1-0
# Agustín Martegani  -,-,Grandes ocasiones creadas: 1      3       3-4
# Agustín Martegani  Ocasiones claras falladas: 1,-,-      4       1-1
#
#                              Rival Condicion Local Visitante  \
# Nombre
# Agustín Martegani         Banfield      Away     0         0
# Agustín Martegani      Gimnasia LP      Away     1         0
# Agustín Martegani  Def. y Justicia      Home     3         4
# Agustín Martegani   Argentinos Jrs      Away     1         1
#
#                                        Partido
# Nombre
# Agustín Martegani         Banfield-San Lorenzo
# Agustín Martegani      Gimnasia LP-San Lorenzo
# Agustín Martegani  San Lorenzo-Def. y Justicia
# Agustín Martegani   Argentinos Jrs-San Lorenzo
#                             Equipo  Goles  Asistencias  Entradas  \
# Nombre
# Francisco Pizzini  Def. y Justicia      0            0         0
# Francisco Pizzini  Def. y Justicia      1            2         0
# Francisco Pizzini  Def. y Justicia      0            0         2
#
#                    Goles y Asistencias  Pases acertados  Pases totales  \
# Nombre
# Francisco Pizzini                    0               12             19
# Francisco Pizzini                    3               26             32
# Francisco Pizzini                    0               27             31
#
#                    Porc Efectividad pases  Duelos efectuados  Duelos ganados  \
# Nombre
# Francisco Pizzini                0.490000                 12               3
# Francisco Pizzini                0.801000                 15               4
# Francisco Pizzini                0.744333                 10               6
#
#                    Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Francisco Pizzini                             10                           1
# Francisco Pizzini                             12                           4
# Francisco Pizzini                              7                           3
#
#                    Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Francisco Pizzini                         2                      2
# Francisco Pizzini                         3                      0
# Francisco Pizzini                         3                      3
#
#                    Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Francisco Pizzini               70        M               0            0
# Francisco Pizzini               89        M               1            0
# Francisco Pizzini               77        M               0            2
#
#                    Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Francisco Pizzini                  0                   2                    1
# Francisco Pizzini                  0                   4                    2
# Francisco Pizzini                  0                   0                    0
#
#                    Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Francisco Pizzini         0                  0               0           0
# Francisco Pizzini         0                  0               2           0
# Francisco Pizzini         1                  1               0           2
#
#                    Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Francisco Pizzini          3      34            1                   0
# Francisco Pizzini          3      46            4                   1
# Francisco Pizzini          2      43            2                   2
#
#                    Centros completados  Balones largos intentados  \
# Nombre
# Francisco Pizzini                    0                          2
# Francisco Pizzini                    1                          1
# Francisco Pizzini                    0                          1
#
#                    Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Francisco Pizzini                           2                15       1
# Francisco Pizzini                           0                12       2
# Francisco Pizzini                           1                 8       1
#
#                    Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Francisco Pizzini              1                0
# Francisco Pizzini              2                1
# Francisco Pizzini              1                0
#
#                   Salidas intentadas Salidas completadas Despejes por alto  \
# Nombre
# Francisco Pizzini
# Francisco Pizzini
# Francisco Pizzini
#
#                                               Notas  Fecha Resultado  \
# Nombre
# Francisco Pizzini                             -,-,-      1       1-0
# Francisco Pizzini  -,-,Grandes ocasiones creadas: 1      3       3-4
# Francisco Pizzini                             -,-,-      4       3-2
#
#                          Rival Condicion Local Visitante  \
# Nombre
# Francisco Pizzini     Newell´s      Away     1         0
# Francisco Pizzini  San Lorenzo      Away     3         4
# Francisco Pizzini  Gimnasia LP      Home     3         2
#
#                                        Partido
# Nombre
# Francisco Pizzini     Newell´s-Def. y Justicia
# Francisco Pizzini  San Lorenzo-Def. y Justicia
# Francisco Pizzini  Def. y Justicia-Gimnasia LP
#             Equipo  Goles  Asistencias  Entradas  Goles y Asistencias  \
# Nombre
# Enzo Roldán  Union      0            0         1                    0
# Enzo Roldán  Union      0            0         1                    0
# Enzo Roldán  Union      0            0         1                    0
# Enzo Roldán  Union      1            0         0                    1
#
#              Pases acertados  Pases totales  Porc Efectividad pases  \
# Nombre
# Enzo Roldán                2              2                0.133333
# Enzo Roldán               12             15                0.293333
# Enzo Roldán               43             54                0.711111
# Enzo Roldán               15             22                0.468444
#
#              Duelos efectuados  Duelos ganados  Duelos en el suelo efectuados  \
# Nombre
# Enzo Roldán                  1               1                              1
# Enzo Roldán                  7               5                              6
# Enzo Roldán                 11               8                             11
# Enzo Roldán                 12               7                              8
#
#              Duelos en el suelo ganados  Duelos aéreos efectuados  \
# Nombre
# Enzo Roldán                           1                         0
# Enzo Roldán                           5                         1
# Enzo Roldán                           8                         0
# Enzo Roldán                           5                         4
#
#              Duelos aereos ganados  Minutos jugados Posicion  Tiros a puerta  \
# Nombre
# Enzo Roldán                      0               12        M               0
# Enzo Roldán                      0               33        M               0
# Enzo Roldán                      0               80        M               0
# Enzo Roldán                      2               62        M               1
#
#              Tiros fuera  Disparos bloq ATA  Regates intentados  \
# Nombre
# Enzo Roldán            0                  0                   0
# Enzo Roldán            0                  0                   2
# Enzo Roldán            1                  0                   5
# Enzo Roldán            0                  0                   2
#
#              Regates completados  Despejes  Disparos Bloq Def  Intercepciones  \
# Nombre
# Enzo Roldán                    0         0                  0               0
# Enzo Roldán                    2         1                  2               0
# Enzo Roldán                    3         0                  0               0
# Enzo Roldán                    2         1                  0               1
#
#              Entradas.1  Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Enzo Roldán           1          0       4            0                   1
# Enzo Roldán           1          0      27            0                   0
# Enzo Roldán           1          0      70            1                   1
# Enzo Roldán           0          0      36            1                   2
#
#              Centros completados  Balones largos intentados  \
# Nombre
# Enzo Roldán                    0                          1
# Enzo Roldán                    0                          2
# Enzo Roldán                    0                          8
# Enzo Roldán                    1                          3
#
#              Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Enzo Roldán                           1                 1       0
# Enzo Roldán                           1                 6       1
# Enzo Roldán                           3                17       1
# Enzo Roldán                           0                10       2
#
#              Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Enzo Roldán              0                0
# Enzo Roldán              2                0
# Enzo Roldán              4                0
# Enzo Roldán              3                0
#
#             Salidas intentadas Salidas completadas Despejes por alto  Notas  \
# Nombre
# Enzo Roldán                                                           -,-,-
# Enzo Roldán                                                           -,-,-
# Enzo Roldán                                                           -,-,-
# Enzo Roldán                                                           -,-,-
#
#              Fecha Resultado         Rival Condicion Local Visitante  \
# Nombre
# Enzo Roldán      1       1-0         River      Home     1         0
# Enzo Roldán      2       0-0      Talleres      Away     0         0
# Enzo Roldán      3       1-0  Atl. Tucuman      Home     1         0
# Enzo Roldán      4       2-1     Sarmiento      Away     2         1
#
#                         Partido
# Nombre
# Enzo Roldán         Union-River
# Enzo Roldán      Talleres-Union
# Enzo Roldán  Union-Atl. Tucuman
# Enzo Roldán     Sarmiento-Union
#                Equipo  Goles  Asistencias  Entradas  Goles y Asistencias  \
# Nombre
# Enzo Fernández  River      0            0         0                    0
# Enzo Fernández  River      0            1         4                    1
# Enzo Fernández  River      0            0         0                    0
# Enzo Fernández  River      0            1         1                    1
#
#                 Pases acertados  Pases totales  Porc Efectividad pases  \
# Nombre
# Enzo Fernández               33             41                0.648889
# Enzo Fernández               66             81                0.810000
# Enzo Fernández               46             59                0.780000
# Enzo Fernández               44             60                0.730000
#
#                 Duelos efectuados  Duelos ganados  \
# Nombre
# Enzo Fernández                  6               4
# Enzo Fernández                 10               8
# Enzo Fernández                  9               4
# Enzo Fernández                  9               3
#
#                 Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Enzo Fernández                              4                           2
# Enzo Fernández                              9                           8
# Enzo Fernández                              6                           3
# Enzo Fernández                              7                           3
#
#                 Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Enzo Fernández                         2                      2
# Enzo Fernández                         1                      0
# Enzo Fernández                         3                      1
# Enzo Fernández                         2                      0
#
#                 Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Enzo Fernández               73        M               0            0
# Enzo Fernández               90        M               0            2
# Enzo Fernández               90        M               0            2
# Enzo Fernández               90        M               1            1
#
#                 Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Enzo Fernández                  0                   0                    0
# Enzo Fernández                  0                   2                    2
# Enzo Fernández                  0                   0                    0
# Enzo Fernández                  0                   2                    1
#
#                 Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Enzo Fernández         0                  0               0           0
# Enzo Fernández         1                  0               1           4
# Enzo Fernández         1                  0               1           0
# Enzo Fernández         0                  0               0           1
#
#                 Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Enzo Fernández          1      53            0                   0
# Enzo Fernández          1      96            3                   1
# Enzo Fernández          0      74            2                   1
# Enzo Fernández          2      76            6                   1
#
#                 Centros completados  Balones largos intentados  \
# Nombre
# Enzo Fernández                    0                          4
# Enzo Fernández                    0                          7
# Enzo Fernández                    0                          7
# Enzo Fernández                    1                          6
#
#                 Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Enzo Fernández                           2                15       0
# Enzo Fernández                           5                16       0
# Enzo Fernández                           3                18       3
# Enzo Fernández                           4                20       0
#
#                 Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Enzo Fernández              2                0
# Enzo Fernández              2                0
# Enzo Fernández              3                0
# Enzo Fernández              1                0
#
#                Salidas intentadas Salidas completadas Despejes por alto  \
# Nombre
# Enzo Fernández
# Enzo Fernández
# Enzo Fernández
# Enzo Fernández
#
#                 Notas  Fecha Resultado        Rival Condicion Local Visitante  \
# Nombre
# Enzo Fernández  -,-,-      1       1-0        Union      Away     1         0
# Enzo Fernández  -,-,-      2       4-1    Patronato      Home     4         1
# Enzo Fernández  -,-,-      3       0-2     Newell´s      Away     0         2
# Enzo Fernández  -,-,-      4       2-2  Racing Club      Home     2         2
#
#                           Partido
# Nombre
# Enzo Fernández        Union-River
# Enzo Fernández    River-Patronato
# Enzo Fernández     Newell´s-River
# Enzo Fernández  River-Racing Club
#                      Equipo  Goles  Asistencias  Entradas  \
# Nombre
# Brahian Alemán  Gimnasia LP      0            0         1
# Brahian Alemán  Gimnasia LP      0            0         0
# Brahian Alemán  Gimnasia LP      0            0         4
# Brahian Alemán  Gimnasia LP      0            0         1
#
#                 Goles y Asistencias  Pases acertados  Pases totales  \
# Nombre
# Brahian Alemán                    0               10             16
# Brahian Alemán                    0               36             50
# Brahian Alemán                    0               18             25
# Brahian Alemán                    0               30             35
#
#                 Porc Efectividad pases  Duelos efectuados  Duelos ganados  \
# Nombre
# Brahian Alemán                   0.630                 15               8
# Brahian Alemán                   0.712                 18               8
# Brahian Alemán                   0.720                 16               9
# Brahian Alemán                   0.860                 10               5
#
#                 Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Brahian Alemán                             12                           7
# Brahian Alemán                             16                           7
# Brahian Alemán                             13                           8
# Brahian Alemán                              7                           4
#
#                 Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Brahian Alemán                         3                      1
# Brahian Alemán                         2                      1
# Brahian Alemán                         3                      1
# Brahian Alemán                         3                      1
#
#                 Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Brahian Alemán               90        M               1            1
# Brahian Alemán               89        M               3            1
# Brahian Alemán               90        M               3            1
# Brahian Alemán               90        M               1            2
#
#                 Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Brahian Alemán                  1                   4                    2
# Brahian Alemán                  1                   3                    0
# Brahian Alemán                  2                   4                    3
# Brahian Alemán                  0                   1                    1
#
#                 Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Brahian Alemán         1                  0               0           1
# Brahian Alemán         2                  0               0           0
# Brahian Alemán         1                  1               1           4
# Brahian Alemán         2                  1               1           1
#
#                 Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Brahian Alemán          0      46            2                   8
# Brahian Alemán          1      87            4                  10
# Brahian Alemán          0      63            2                  13
# Brahian Alemán          0      73            5                  13
#
#                 Centros completados  Balones largos intentados  \
# Nombre
# Brahian Alemán                    4                          4
# Brahian Alemán                    2                          5
# Brahian Alemán                    2                          2
# Brahian Alemán                    4                          5
#
#                 Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Brahian Alemán                           2                19       0
# Brahian Alemán                           2                31       2
# Brahian Alemán                           1                23       3
# Brahian Alemán                           4                25       0
#
#                 Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Brahian Alemán              4                0
# Brahian Alemán              7                0
# Brahian Alemán              1                0
# Brahian Alemán              2                1
#
#                Salidas intentadas Salidas completadas Despejes por alto  \
# Nombre
# Brahian Alemán
# Brahian Alemán
# Brahian Alemán
# Brahian Alemán
#
#                                                             Notas  Fecha  \
# Nombre
# Brahian Alemán                                              -,-,-      1
# Brahian Alemán                                              -,-,-      2
# Brahian Alemán  Penalti provocado: 1,-,Grandes ocasiones cread...      3
# Brahian Alemán                                              -,-,-      4
#
#                Resultado            Rival Condicion Local Visitante  \
# Nombre
# Brahian Alemán       0-0      Racing Club      Away     0         0
# Brahian Alemán       1-0      San Lorenzo      Home     1         0
# Brahian Alemán       4-0         Banfield      Away     4         0
# Brahian Alemán       3-2  Def. y Justicia      Away     3         2
#
#                                     Partido
# Nombre
# Brahian Alemán      Racing Club-Gimnasia LP
# Brahian Alemán      Gimnasia LP-San Lorenzo
# Brahian Alemán         Banfield-Gimnasia LP
# Brahian Alemán  Def. y Justicia-Gimnasia LP
#                      Equipo  Goles  Asistencias  Entradas  \
# Nombre
# Jorge Morel  Estudiantes LP      0            0         2
# Jorge Morel  Estudiantes LP      0            0         3
# Jorge Morel  Estudiantes LP      0            1         0
#
#              Goles y Asistencias  Pases acertados  Pases totales  \
# Nombre
# Jorge Morel                    0                3              4
# Jorge Morel                    0                9             11
# Jorge Morel                    1               21             33
#
#              Porc Efectividad pases  Duelos efectuados  Duelos ganados  \
# Nombre
# Jorge Morel                0.191667                  8               5
# Jorge Morel                0.546667                  8               5
# Jorge Morel                0.483556                  9               4
#
#              Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Jorge Morel                              4                           3
# Jorge Morel                              6                           3
# Jorge Morel                              1                           0
#
#              Duelos aéreos efectuados  Duelos aereos ganados  Minutos jugados  \
# Nombre
# Jorge Morel                         4                      2               23
# Jorge Morel                         2                      2               60
# Jorge Morel                         8                      4               68
#
#             Posicion  Tiros a puerta  Tiros fuera  Disparos bloq ATA  \
# Nombre
# Jorge Morel        M               0            0                  0
# Jorge Morel        M               0            1                  1
# Jorge Morel        M               0            0                  0
#
#              Regates intentados  Regates completados  Despejes  \
# Nombre
# Jorge Morel                   0                    0         1
# Jorge Morel                   0                    0         0
# Jorge Morel                   0                    0         1
#
#              Disparos Bloq Def  Intercepciones  Entradas.1  Regateado  Toques  \
# Nombre
# Jorge Morel                  0               0           2          0       9
# Jorge Morel                  0               0           3          0      16
# Jorge Morel                  0               1           0          0      41
#
#              Pases clave  Centros intentados  Centros completados  \
# Nombre
# Jorge Morel            0                   0                    0
# Jorge Morel            0                   0                    0
# Jorge Morel            2                   2                    1
#
#              Balones largos intentados  Balones largos completados  \
# Nombre
# Jorge Morel                          0                           0
# Jorge Morel                          1                           1
# Jorge Morel                          3                           0
#
#              Posesion perdida  Faltas  Recibió falta  Fueras de juego Paradas  \
# Nombre
# Jorge Morel                 1       1              1                0
# Jorge Morel                 2       3              0                0
# Jorge Morel                15       1              0                0
#
#             Con los puños Salidas intentadas Salidas completadas  \
# Nombre
# Jorge Morel
# Jorge Morel
# Jorge Morel
#
#             Despejes por alto  Notas  Fecha Resultado          Rival  \
# Nombre
# Jorge Morel                    -,-,-      1       2-1  Independiente
# Jorge Morel                    -,-,-      2       2-3     CA Huracan
# Jorge Morel                    -,-,-      4       3-2        Arsenal
#
#             Condicion Local Visitante                       Partido
# Nombre
# Jorge Morel      Home     2         1  Estudiantes LP-Independiente
# Jorge Morel      Away     2         3     CA Huracan-Estudiantes LP
# Jorge Morel      Home     3         2        Estudiantes LP-Arsenal
#                        Equipo  Goles  Asistencias  Entradas  \
# Nombre
# Manuel Castro  Estudiantes LP      0            1         2
# Manuel Castro  Estudiantes LP      0            0         0
# Manuel Castro  Estudiantes LP      0            0         4
# Manuel Castro  Estudiantes LP      0            0         0
#
#                Goles y Asistencias  Pases acertados  Pases totales  \
# Nombre
# Manuel Castro                    1               11             15
# Manuel Castro                    0                4              8
# Manuel Castro                    0               18             23
# Manuel Castro                    0               12             22
#
#                Porc Efectividad pases  Duelos efectuados  Duelos ganados  \
# Nombre
# Manuel Castro                0.543444                  7               3
# Manuel Castro                0.150000                  5               2
# Manuel Castro                0.684667                 14               7
# Manuel Castro                0.446111                 12               4
#
#                Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Manuel Castro                              4                           2
# Manuel Castro                              3                           0
# Manuel Castro                             10                           6
# Manuel Castro                              4                           1
#
#                Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Manuel Castro                         3                      1
# Manuel Castro                         2                      2
# Manuel Castro                         4                      1
# Manuel Castro                         8                      3
#
#                Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Manuel Castro               67        M               0            0
# Manuel Castro               27        M               0            0
# Manuel Castro               79        M               0            1
# Manuel Castro               73        M               0            0
#
#                Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Manuel Castro                  0                   0                    0
# Manuel Castro                  0                   0                    0
# Manuel Castro                  3                   3                    1
# Manuel Castro                  0                   2                    0
#
#                Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Manuel Castro         1                  0               1           2
# Manuel Castro         1                  0               0           0
# Manuel Castro         0                  0               2           4
# Manuel Castro         0                  0               1           0
#
#                Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Manuel Castro          2      27            1                   3
# Manuel Castro          0      13            2                   0
# Manuel Castro          2      52            3                   6
# Manuel Castro          0      38            0                   4
#
#                Centros completados  Balones largos intentados  \
# Nombre
# Manuel Castro                    1                          5
# Manuel Castro                    0                          0
# Manuel Castro                    1                          4
# Manuel Castro                    1                          0
#
#                Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Manuel Castro                           3                 9       0
# Manuel Castro                           0                 6       2
# Manuel Castro                           4                17       0
# Manuel Castro                           0                21       0
#
#                Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Manuel Castro              0                0
# Manuel Castro              0                0
# Manuel Castro              1                0
# Manuel Castro              1                0
#
#               Salidas intentadas Salidas completadas Despejes por alto  \
# Nombre
# Manuel Castro
# Manuel Castro
# Manuel Castro
# Manuel Castro
#
#                                           Notas  Fecha Resultado  \
# Nombre
# Manuel Castro  -,-,Grandes ocasiones creadas: 1      1       2-1
# Manuel Castro                             -,-,-      2       2-3
# Manuel Castro  -,-,Grandes ocasiones creadas: 1      3       2-1
# Manuel Castro                             -,-,-      4       3-2
#
#                        Rival Condicion Local Visitante  \
# Nombre
# Manuel Castro  Independiente      Home     2         1
# Manuel Castro     CA Huracan      Away     2         3
# Manuel Castro          Lanús      Home     2         1
# Manuel Castro        Arsenal      Home     3         2
#
#                                     Partido
# Nombre
# Manuel Castro  Estudiantes LP-Independiente
# Manuel Castro     CA Huracan-Estudiantes LP
# Manuel Castro          Estudiantes LP-Lanús
# Manuel Castro        Estudiantes LP-Arsenal
#                      Equipo  Goles  Asistencias  Entradas  \
# Nombre
# Carlos Alcaraz  Racing Club      0            0         4
# Carlos Alcaraz  Racing Club      0            0         0
# Carlos Alcaraz  Racing Club      1            0         0
# Carlos Alcaraz  Racing Club      0            0         0
#
#                 Goles y Asistencias  Pases acertados  Pases totales  \
# Nombre
# Carlos Alcaraz                    0                5              8
# Carlos Alcaraz                    0                0              0
# Carlos Alcaraz                    1               10             12
# Carlos Alcaraz                    0               13             16
#
#                 Porc Efectividad pases  Duelos efectuados  Duelos ganados  \
# Nombre
# Carlos Alcaraz                0.154000                 12               6
# Carlos Alcaraz                0.000000                  3               3
# Carlos Alcaraz                0.627111                  7               4
# Carlos Alcaraz                0.675000                  9               3
#
#                 Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Carlos Alcaraz                              9                           6
# Carlos Alcaraz                              3                           3
# Carlos Alcaraz                              3                           1
# Carlos Alcaraz                              9                           3
#
#                 Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Carlos Alcaraz                         3                      0
# Carlos Alcaraz                         0                      0
# Carlos Alcaraz                         4                      3
# Carlos Alcaraz                         0                      0
#
#                 Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Carlos Alcaraz               22        M               0            0
# Carlos Alcaraz                1        M               0            0
# Carlos Alcaraz               68        M               2            0
# Carlos Alcaraz               75        M               0            0
#
#                 Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Carlos Alcaraz                  1                   2                    1
# Carlos Alcaraz                  0                   2                    2
# Carlos Alcaraz                  2                   2                    1
# Carlos Alcaraz                  2                   3                    1
#
#                 Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Carlos Alcaraz         1                  0               0           4
# Carlos Alcaraz         0                  0               0           0
# Carlos Alcaraz         0                  0               0           0
# Carlos Alcaraz         2                  0               1           0
#
#                 Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Carlos Alcaraz          1      22            1                   1
# Carlos Alcaraz          0       5            0                   2
# Carlos Alcaraz          1      20            1                   0
# Carlos Alcaraz          1      36            0                   0
#
#                 Centros completados  Balones largos intentados  \
# Nombre
# Carlos Alcaraz                    1                          2
# Carlos Alcaraz                    0                          0
# Carlos Alcaraz                    0                          3
# Carlos Alcaraz                    0                          4
#
#                 Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Carlos Alcaraz                           1                 5       1
# Carlos Alcaraz                           0                 2       0
# ...
# Luca Orellano               26        M               0            0
# Luca Orellano               89        M               1            1
# Luca Orellano               89        M               0            1
#
#                Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Luca Orellano                  0                   5                    3
# Luca Orellano                  0                   4                    1
# Luca Orellano                  1                   2                    1
# Luca Orellano                  0                   7                    3
#
#                Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Luca Orellano         0                  0               0           2
# Luca Orellano         0                  0               0           1
# Luca Orellano         0                  0               1           3
# Luca Orellano         0                  0               1           1
#
#                Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Luca Orellano          2      54            1                   6
# Luca Orellano          0      21            0                   0
# Luca Orellano          0      40            2                   3
# Luca Orellano          2      62            4                   7
#
#                Centros completados  Balones largos intentados  \
# Nombre
# Luca Orellano                    2                          2
# Luca Orellano                    0                          1
# Luca Orellano                    2                          3
# Luca Orellano                    2                          1
#
#                Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Luca Orellano                           0                20       1
# Luca Orellano                           0                 6       0
# Luca Orellano                           2                 8       1
# Luca Orellano                           0                25       0
#
#                Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Luca Orellano              4                0
# Luca Orellano              1                0
# Luca Orellano              2                0
# Luca Orellano              0                0
#
#               Salidas intentadas Salidas completadas Despejes por alto  Notas  \
# Nombre
# Luca Orellano                                                           -,-,-
# Luca Orellano                                                           -,-,-
# Luca Orellano                                                           -,-,-
# Luca Orellano                                                           -,-,-
#
#                Fecha Resultado           Rival Condicion Local Visitante  \
# Nombre
# Luca Orellano      1       2-0        Aldosivi      Home     2         0
# Luca Orellano      2       1-0  Rosario Ctral.      Away     1         0
# Luca Orellano      3       0-0   Independiente      Home     0         0
# Luca Orellano      4       2-0      CA Huracan      Away     2         0
#
#                                       Partido
# Nombre
# Luca Orellano        Velez Sarsfield-Aldosivi
# Luca Orellano  Rosario Ctral.-Velez Sarsfield
# Luca Orellano   Velez Sarsfield-Independiente
# Luca Orellano      CA Huracan-Velez Sarsfield
#                   Equipo  Goles  Asistencias  Entradas  Goles y Asistencias  \
# Nombre
# Edwin Mosquera  Aldosivi      0            0         0                    0
# Edwin Mosquera  Aldosivi      0            0         2                    0
# Edwin Mosquera  Aldosivi      0            1         1                    1
#
#                 Pases acertados  Pases totales  Porc Efectividad pases  \
# Nombre
# Edwin Mosquera               13             16                0.603000
# Edwin Mosquera               14             20                0.700000
# Edwin Mosquera                6              7                0.554222
#
#                 Duelos efectuados  Duelos ganados  \
# Nombre
# Edwin Mosquera                 10               4
# Edwin Mosquera                 10               8
# Edwin Mosquera                  9               5
#
#                 Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Edwin Mosquera                             10                           4
# Edwin Mosquera                             10                           8
# Edwin Mosquera                              8                           5
#
#                 Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Edwin Mosquera                         0                      0
# Edwin Mosquera                         0                      0
# Edwin Mosquera                         1                      0
#
#                 Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Edwin Mosquera               67        M               1            0
# Edwin Mosquera               90        M               1            1
# Edwin Mosquera               58        M               0            0
#
#                 Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Edwin Mosquera                  1                   6                    4
# Edwin Mosquera                  0                   3                    2
# Edwin Mosquera                  0                   0                    0
#
#                 Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Edwin Mosquera         0                  0               0           0
# Edwin Mosquera         1                  0               0           2
# Edwin Mosquera         0                  0               0           1
#
#                 Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Edwin Mosquera          2      39            0                   3
# Edwin Mosquera          0      47            0                   5
# Edwin Mosquera          2      20            1                   3
#
#                 Centros completados  Balones largos intentados  \
# Nombre
# Edwin Mosquera                    0                          1
# Edwin Mosquera                    0                          4
# Edwin Mosquera                    1                          0
#
#                 Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Edwin Mosquera                           0                16       1
# Edwin Mosquera                           1                18       0
# Edwin Mosquera                           0                 5       1
#
#                 Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Edwin Mosquera              0                0
# Edwin Mosquera              4                0
# Edwin Mosquera              4                0
#
#                Salidas intentadas Salidas completadas Despejes por alto  \
# Nombre
# Edwin Mosquera
# Edwin Mosquera
# Edwin Mosquera
#
#                                            Notas  Fecha Resultado  \
# Nombre
# Edwin Mosquera                             -,-,-      1       2-0
# Edwin Mosquera                             -,-,-      2       1-2
# Edwin Mosquera  -,-,Grandes ocasiones creadas: 1      3       0-2
#
#                           Rival Condicion Local Visitante  \
# Nombre
# Edwin Mosquera  Velez Sarsfield      Away     2         0
# Edwin Mosquera             Boca      Home     1         2
# Edwin Mosquera       Godoy Cruz      Away     0         2
#
#                                  Partido
# Nombre
# Edwin Mosquera  Velez Sarsfield-Aldosivi
# Edwin Mosquera             Aldosivi-Boca
# Edwin Mosquera       Godoy Cruz-Aldosivi
#                 Equipo  Goles  Asistencias  Entradas  Goles y Asistencias  \
# Nombre
# Cristian Zabala  Tigre      0            0         2                    0
# Cristian Zabala  Tigre      0            0         0                    0
# Cristian Zabala  Tigre      0            0         0                    0
# Cristian Zabala  Tigre      0            0         0                    0
#
#                  Pases acertados  Pases totales  Porc Efectividad pases  \
# Nombre
# Cristian Zabala               15             23                0.469444
# Cristian Zabala               46             57                0.810000
# Cristian Zabala               10             11                0.151667
# Cristian Zabala               18             18                0.288889
#
#                  Duelos efectuados  Duelos ganados  \
# Nombre
# Cristian Zabala                 16               8
# Cristian Zabala                 10               5
# Cristian Zabala                  3               2
# Cristian Zabala                  4               1
#
#                  Duelos en el suelo efectuados  Duelos en el suelo ganados  \
# Nombre
# Cristian Zabala                             11                           5
# Cristian Zabala                              7                           3
# Cristian Zabala                              3                           2
# Cristian Zabala                              3                           1
#
#                  Duelos aéreos efectuados  Duelos aereos ganados  \
# Nombre
# Cristian Zabala                         5                      3
# Cristian Zabala                         3                      2
# Cristian Zabala                         0                      0
# Cristian Zabala                         1                      0
#
#                  Minutos jugados Posicion  Tiros a puerta  Tiros fuera  \
# Nombre
# Cristian Zabala               65        M               0            0
# Cristian Zabala               90        M               1            2
# Cristian Zabala               15        M               0            1
# Cristian Zabala               26        M               0            0
#
#                  Disparos bloq ATA  Regates intentados  Regates completados  \
# Nombre
# Cristian Zabala                  1                   2                    2
# Cristian Zabala                  1                   3                    2
# Cristian Zabala                  0                   1                    1
# Cristian Zabala                  0                   1                    0
#
#                  Despejes  Disparos Bloq Def  Intercepciones  Entradas.1  \
# Nombre
# Cristian Zabala         1                  0               1           2
# Cristian Zabala         0                  0               1           0
# Cristian Zabala         0                  0               0           0
# Cristian Zabala         0                  0               0           0
#
#                  Regateado  Toques  Pases clave  Centros intentados  \
# Nombre
# Cristian Zabala          3      41            1                   2
# Cristian Zabala          2      71            3                   0
# Cristian Zabala          1      14            0                   0
# Cristian Zabala          0      24            1                   1
#
#                  Centros completados  Balones largos intentados  \
# Nombre
# Cristian Zabala                    0                          4
# Cristian Zabala                    0                          7
# Cristian Zabala                    0                          0
# Cristian Zabala                    1                          2
#
#                  Balones largos completados  Posesion perdida  Faltas  \
# Nombre
# Cristian Zabala                           0                17       2
# Cristian Zabala                           4                14       0
# Cristian Zabala                           0                 1       0
# Cristian Zabala                           2                 3       1
#
#                  Recibió falta  Fueras de juego Paradas Con los puños  \
# Nombre
# Cristian Zabala              1                0
# Cristian Zabala              1                0
# Cristian Zabala              1                0
# Cristian Zabala              1                0
#
#                 Salidas intentadas Salidas completadas Despejes por alto  \
# Nombre
# Cristian Zabala
# Cristian Zabala
# Cristian Zabala
# Cristian Zabala
#
#                  Notas  Fecha Resultado            Rival Condicion Local  \
# Nombre
# Cristian Zabala  -,-,-      1       1-1       Godoy Cruz      Away     1
# Cristian Zabala  -,-,-      2       1-1      Central CBA      Home     1
# Cristian Zabala  -,-,-      3       0-2  Barracas Ctral.      Away     0
# Cristian Zabala  -,-,-      4       0-0            Lanús      Away     0
#
#                 Visitante                Partido
# Nombre
# Cristian Zabala         1       Godoy Cruz-Tigre
# Cristian Zabala         1      Tigre-Central CBA
# Cristian Zabala         2  Barracas Ctral.-Tigre
# Cristian Zabala         0            Lanús-Tigre
